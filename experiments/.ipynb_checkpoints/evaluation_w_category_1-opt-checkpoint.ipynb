# %% [markdown]
# # 定量的な評価方法（前処理1 & 最適化したパラメータ）
#
# ## 目的
# カテゴリデータ（= 教師データ）を用いて定量的評価を行い、
# "evaluation_w_category_1-default.ipynb"(前処理1 & デフォルトパラメータ)の場合と比較する。
#
# ## モデル
# doc2vec_pp1_setup1-opt.model
# ("exp_params_setup1.ipynb"で、ハイパーパラメータを最適化したモデル)
#
# ## 評価方法
# "evaluation_w_category_1-default.ipynb"(**以下、デフォルトモデル**)と同じ。
#
# ## 結果
# ### 評価方法1
# 傾向はデフォルトモデルと同じ:
# """dokujo-tsushin, movie-enter, smaxなどは、比較的よくラベル分けとカテゴリが一致している（70~80%）。
# 一方で、kaden-cghannel, livedoor-hommeなどはあまり一致していない。"""
# 似た傾向のあるカテゴリでは、切り分けが難しいということだろう。
#
# ただし正解率は、全体的に底上げされている。
# doc2vecのベクトル情報が、デフォルトモデルより適切に取得できていることがわかる。
#
# t-SNEのplotで見ても、カテゴリ分けがかなりきれいにできていることがわかる。
#
# ### 評価方法2
# #### 2-1. 正解率による評価
# 正解率（accuracy）は91%。
# デフォルトモデルの79%と比べて大幅に改善した。
#
# #### 2-2. 9つのカテゴリ毎にも評価値を算出
# 一番低いlivedoor-hommeでもf1 score=80%, 一番高いmovie-enterで96%の
# 値が出ている。
#
# #### 2-3. 正しく予測した記事と、間違って予測した記事の比較
# 正解しているケースでは、「そのカテゴリらしい」記事内容を適切に予測できている。
#
# 間違いのケースは、
# 競馬記事のように明らかに間違いの記事もあり、doc2vecの精度にまだ改善の余地はあることがわかる。
# とはいえ、明らかに間違えたのは（間違えた例で表示した10件中）この１件のみで、他の間違いは
# - （似たカテゴリを予測しているので）大きく外してないが、doc2vecの精度を上げれば正解できそうなケース
# - 記事内容的には、"間違って予測した"カテゴリでも問題ないケース
#
# ## 結論
# 上記のカテゴリ予測モデルの正解率が91%と高いことと、記事の比較から、
# doc2vecの精度は、デフォルトモデルに比べて大幅に改善していることがわかる。

# %%
import sys
import os.path as osp
sys.path.append(osp.pardir)
import pickle
from utils import train_docs
from utils import evaluation_docs
from gensim.models.doc2vec import Doc2Vec

fn_model = './model/doc2vec_pp1_setup1-opt.model'
fn_tagged_words_list = './preproc_data/words_list_mecab_pp1.pickle'
fn_category_map = './preproc_data/category_map_pp1.pickle'
n_clusters = 20
n_each_show = 5

model = Doc2Vec.load(fn_model)
tagged_words_list = pickle.load(open(fn_tagged_words_list, 'rb'))
dic_category_map = pickle.load(open(fn_category_map, 'rb'))

ed = evaluation_docs.evaluation_labeled_docs(model, tagged_words_list, n_clusters, dic_category_map)
# Out:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## 1. Kmeansで学習したラベルとカテゴリの一致度

# %%
ed.eval_km_cat()
ed.plot2d('PCA', n_sample=None, label_kind='category')
ed.plot2d('t-SNE', n_sample=3000, label_kind='category')
# Out:
# dokujo-tsushin 0.7453917050691244
# it-life-hack 0.6632183908045977
# kaden-channel 0.3058252427184466
# livedoor-homme 0.31237721021611004
# movie-enter 0.9170506912442397
# peachy 0.6750599520383693
# smax 0.903448275862069
# sports-watch 0.7953020134228188
# topic-news 0.9270557029177718

# %% [markdown]
# ## 2. 教師ありモデル（Neural net）を用いた評価
#
# 正解率は91%で、デフォルトモデルの79%を大きく上回る。
# カテゴリ別に見ても、一番低いlivedoor-hommeでもf1 score=80%, 一番高いmovie-enterで96%の
# 値が出ている。

# %%
mlp_model, score, history = ed.eval_sv(save_path=None, show_each_cat=True)
# Out:
# MLP data:
#    5832 train samples
#    1459 test samples
#
# MLP score:
#   Test loss: 0.3785217425200611
#   Test accuracy: 0.9095270737055804
#   Epoch: 173
#                  precision    recall  f1-score   support
#
# dokujo-tsushin       0.91      0.91      0.91       173
#   it-life-hack       0.93      0.90      0.91       174
#  kaden-channel       0.86      0.85      0.86       165
# livedoor-homme       0.81      0.79      0.80       102
#    movie-enter       0.97      0.95      0.96       174
#         peachy       0.86      0.90      0.88       167
#           smax       0.94      0.97      0.95       174
#   sports-watch       0.96      0.92      0.94       179
#     topic-news       0.90      0.95      0.92       151
#
#    avg / total       0.91      0.91      0.91      1459

# %% [markdown]
# ## 正解した記事と間違った記事の比較
#
# ### 正しく予測した記事
# 該当カテゴリ"らしい"記事が適切に予測されている。
#
# ### 間違って予測した記事
# 以下にいくつかの例をピックアップ。
#
# **tag: t4760
# pred_cat: it-life-hack
# real_cat: sports-watch**
#
# 競馬の記事なのに、なぜかIT系を予測してしまった例。記事中に「数字」がたくさん入っている。
# IT記事にもスペックや値段を表す「数字」がよく現れるため、これらとの切り分けができなかったのだろう。
# doc2vecの学習精度にまだ改善余地があることがわかる例といえる。
#
# **tag: t4465
# pred_cat: smax
# real_cat: peachy**
#
# これは記事内容的にはアプリの話なので、peachyというよりsmaxに振り分けられても問題ない例。
#
# **tag: t4108
# pred_cat: dokujo-tsushin
# real_cat: peachy**
#
# 予測も実測も女性系のカテゴリだが、内容的には美容系なので、これはdoc2vecの精度が上がれば、
# 予測を間違えない例だろう。
#
# **tag: t3212
# pred_cat: sports-watch
# real_cat: topic-news**
#
# **tag: t5600
# pred_cat: movie-enter
# real_cat: dokujo-tsushin**
#
# いずれも内容的には、予測カテゴリにあってもおかしくない記事。間違っても問題ない例といえる。
#
# ### 結論
# 下記の**正解した記事と間違った記事の比較**を見ると、
# 競馬記事のように明らかに間違いの記事もあり、doc2vecの精度にまだ改善の余地はあることがわかる。
# とはいえ、明らかに間違えたのは（間違えた例で表示した10件中）この１件のみで、他の間違いは
# - （似たカテゴリを予測しているので）大きく外してないが、doc2vecの精度を上げれば正解できそうなケース
# - 記事内容的には、"間違って予測した"カテゴリでも問題ないケース
#
# 上記のカテゴリ予測モデルの正解率が91%と高いことと、この比較から、
# doc2vecの精度はかなり良くなっていることがわかる。

# %%
# 準備
from collections import defaultdict
pred_cats = mlp_model.predict_classes(ed.x_test)
y_test_int = [list(y).index(1) for y in ed.y_test]

dic_test_results = defaultdict(dict)
for pred_cat, real_cat, index in zip(pred_cats, y_test_int, ed.indices_test):
    tagged_words = tagged_words_list[index]
    words = tagged_words[0]
    tag = tagged_words.tags[0]
    dic_test_results[tag]['words'] = words
    dic_test_results[tag]['pred_cat'] = ed.le.inverse_transform(pred_cat)
    dic_test_results[tag]['real_cat'] = ed.le.inverse_transform(real_cat)
    dic_test_results[tag]['correct'] = pred_cat == real_cat
# Out:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ...
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/usr0102292/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# 正解した記事と間違った記事を表示
n_show = 10
seed = 7

dic_correct = {k: v for k, v in dic_test_results.items() if v['correct']==1}
dic_wrong = {k: v for k, v in dic_test_results.items() if v['correct']==0}

random_wrong_tags = np.random.permutation(list(dic_wrong.keys()))

def print_results(dic, n_show, seed=0):
    np.random.seed(seed)
    random_tags = np.random.permutation(list(dic.keys()))
    for tag in random_tags[:n_show]:
        result = dic[tag]
        template = 'tag: {tag}\npred_cat: {pred_cat}\nreal_cat: {real_cat}\nwords:{words}'
        print(template.format(tag=tag, **result), end='\n\n')

#予測が正解した記事
print('\n=== Correct predictions ===')
print_results(dic_correct, n_show, seed)

#予測が間違った記事
print('\n=== Wrong predictions ===')
print_results(dic_wrong, n_show, seed)
# Out:
# === Correct predictions ===
# tag: t7139
# pred_cat: smax
# real_cat: smax
# words:['NTTドコモ', '、', 'Xperia GX', 'SO', '-', '04', 'D', 'と', 'Xperia SX', 'SO', '-', '05', 'D', 'の', '発売日', 'を', '正式決定', '！', '入荷', '数少なく', '予約', 'が', '必要', '？', 'Xperia GX', 'SO', '-', '04', 'D', 'と', 'Xperia SX', 'SO', '-', '05', 'D', 'の', '発売日', 'が', '決定', '！', 'NTTドコモ', 'は', '6日', '、', '今夏', 'に', '発売', 'する', '予定', 'の', '「', '2012年', '夏モデル', '」', 'の', 'うち', '、', '高速', 'データ通信サービス', '「', 'Xi', '（', 'クロッシィ', '）', '」', 'に', '対応', 'し', 'た', '「', 'Xperia', 'シリーズ', '」', 'の', '最新', 'スマートフォン', '「', 'Xperia GX', 'SO', '-', '04', 'D', '」', 'および', '「', 'Xperia SX', 'SO', '-', '05', 'D', '」', '（', 'ともに', 'ソニーモバイルコミュニケーションズ', '製', '）', 'の', '発売日', 'を', '正式', 'に', '決定', 'し', 'た', 'こと', 'を', '発表', 'し', 'て', 'い', 'ます', '。', '発売日', 'は', '、', 'Xperia GX', 'SO', '-', '04', 'D', 'が', '2012年', '8月9日', '（', '木', '）', '、', 'Xperia SX', 'SO', '-', '05', 'D', 'が', '2012年', '8月10日', '（', '金', '）', 'と', 'なり', 'ます', '。', 'ともに', '先週', 'から', '事前予約', 'が', 'はじまっ', 'て', 'い', 'て', '、', 'Xperia GX', 'SO', '-', '04', 'D', 'は', '2日', '（', '木', '）', 'から', '発売日', 'まで', '、', 'Xperia SX', 'SO', '-', '05', 'D', 'は', '3日', '（', '金', '）', 'から', '発売日', 'まで', 'ドコモショップ', 'など', 'で', '予約', 'を', '受け付け', 'て', 'い', 'ます', '。', 'Xperia GX', 'SO', '-', '04', 'D', 'は', 'ソニー', 'モバイル', 'として', '初', 'の', '高速', 'データ通信サービス', '「', 'Xi', '（', 'クロッシィ', '）', '」', 'に', '対応', 'し', 'た', 'モデル', 'で', '、', '4', '.', '6インチ', '大', '画面', 'HD', 'ディスプレイ', 'や', '1', '.', '5', 'GHz', 'デュアルコア', 'CPU', 'を', '搭載', 'し', '、', 'おサイフケータイ', '（', 'Felica', '）', 'に', '対応', 'し', 'た', 'モデル', 'です', '。', '一方', '、', 'Xperia SX', 'SO', '-', '05', 'D', 'は', 'Xi', '対応', '世界', '最', '軽量', 'スマートフォン', 'と', 'いう', 'だけ', 'で', 'なく', '、', 'おサイフケータイ', '（', 'Felica', '）', 'や', 'ワンセグ', '、', '赤外線', 'に', 'も', '対応', 'し', 'た', 'コンパクト', 'ながら', '基本', '機能', 'に', 'は', 'しっかり', 'と', '利用', 'できる', 'Android 4.0', '（', '開発コード名', '：', 'IceCream', 'Sandwich', '；', 'ICS', '）', '搭載', 'スマートフォン', 'です', '。', 'なお', '、', 'ともに', '出荷台数', 'が', '少なめ', 'と', 'なっ', 'て', 'いる', 'よう', 'で', '、', '特に', 'カラーバリエーション', 'が', '4色', 'と', '多い', 'Xperia SX', 'SO', '-', '05', 'D', 'は', '各', '色', 'を', '入荷', 'する', '関係', 'で', '、', '大都市圏', '以外', 'の', 'ドコモショップ', 'や', '併売', '店', 'など', 'で', 'は', '発売日', 'に', '各', '色', '1', '〜', '2', '台', '程度', 'しか', '入荷', 'し', 'ない', 'という', '店舗', 'が', '多い', 'よう', 'です', 'ので', '、', '確実', 'に', '発売日', 'に', '購入', 'し', 'た', 'い人', 'は', '予約', 'し', 'て', 'おく', 'こと', 'を', 'オススメ', 'し', 'ます', '。', '実際', 'の', '価格', 'や', '入荷', '数', 'に', 'つき', 'まし', 'て', 'は', '、', '購入', 'を', '行う', '予定', 'の', '店舗', 'に', 'お', '問い合わせ', 'ください', '。', '記事', '執筆', '：', 'memn0ck']
#
# tag: t3855
# pred_cat: peachy
# real_cat: peachy
# words:['佐々木希', 'さん', 'が', '美脚', 'スタイル', 'を', '披露', '！', '\u3000', '「', 'タイツ', 'を', '履く', 'の', 'が', 'すごく', '上手', '」', '\u3000', '日々', '寒さ', 'が', '深まり', '、', 'ファッション', 'が', '一番', '楽しい', '冬', 'に', '近付い', 'て', 'き', 'まし', 'た', '。', 'この', 'シーズン', 'だ', 'から', 'こそ', '楽しめる', 'アイテム', 'の', '代表', 'と', 'いえ', 'ば', '、', 'タイツ', '。', '履く', 'だけ', 'で', 'セクシー', 'に', 'も', 'キュート', 'に', 'も', 'できる', '変幻', '自在', 'な', 'タイツ', 'は', '、', '今や', '単なる', '防寒', 'アイテム', 'で', 'は', 'ない', 'です', 'よ', 'ね', '。', '\u3000', '女性', 'らしい', '可愛らし', 'さ', 'と', '、', 'どんな', 'コーディネート', 'に', 'も', 'あう', '磨き', 'やすさ', 'を', '持っ', 'た', 'レッグウェア', 'を', '提案', 'し', 'て', 'いる', '福助', 'の', 'レッグウェア・ブランド', '「', 'エフィング', '」', 'が', '、', 'イメージキャラクター', 'で', 'ある', 'モデル', 'の', '佐々木希', 'さん', 'を', '招い', 'て', '、', '6日', '都内', 'で', 'トークイベント', 'を', '開催', 'いたし', 'まし', 'た', '。', '\u3000', 'プライベート', 'でも', '仕事', 'で', 'も', 'レッグウェア', 'を', 'しょっちゅう', '履く', 'という', '佐々木', 'さん', 'は', '、', '美脚', 'を', '強調', 'し', 'た', '黒', 'の', 'ワンピースとタイツ', '姿', 'の', 'セクシー', 'スタイル', 'で', '登場', 'し', '、', '「', 'タイツ', 'を', '履く', 'の', 'が', 'すごく', '上手', 'らしい', 'です', '。', 'スタイリスト', 'さん', 'と', 'クライアント', 'さん', 'に', '褒め', 'られ', 'まし', 'た', '」', 'と', 'コメント', '。', '履く', 'とき', 'に', '力', '加減', 'など', 'を', '意識', 'し', 'た', 'よう', 'で', '、', '薄い', 'タイツ', 'の', '模様', 'など', 'は', 'まだら', 'に', 'なら', 'ない', 'よう', 'に', '、', '均等', 'に', '履く', 'こと', 'が', 'でき', 'て', '、', '直し', 'が', 'いら', 'なかっ', 'た', 'という', 'エピソード', 'で', '記者', '達', 'を', '驚か', 'せ', 'て', 'い', 'まし', 'た', '。', '\u3000', '自慢', 'の', '美脚', 'の', '維持', 'について', '聞か', 'れる', 'と', '、', '「', 'マッサージ', 'は', 'よく', 'し', 'て', 'ます', 'ね', '。', '老', '廃物', 'を', '外', 'に', '出し', 'て', 'ます', '。', 'それ', 'と', '、', '食べ', 'たい', '時', 'に', 'は', '食べ', 'て', '、', '次', 'の', '日', 'に', '野菜', 'だけ', 'に', 'する', 'とか', '調整', 'し', 'て', 'ます', '」', 'と', 'バランス', 'を', '取り', 'ながら', '維持', 'し', 'て', 'いる', 'こと', 'を', '明かし', 'て', 'くれ', 'まし', 'た', '。', '\u3000', 'また', '、', '佐々木', 'さん', 'が', '24日', 'に', 'クリスマスソング', '「', 'ジン', 'ジン', 'ジングルベル', 'feat', '.', 'Pentaphonic', '」', 'を', 'リリース', 'する', 'こと', 'から', '、', 'クリスマス', 'の', '予定', 'を', '聞か', 'れる', 'と', '「', 'たぶん', '仕事', 'です', '。', 'オフ', 'だっ', 'たら', '、', 'レッグウェア', 'を', '履い', 'て', '表参道', 'の', 'イルミネーション', 'を', '見', 'に', '行き', 'たい', 'です', '!」', 'と', '目', 'を', 'キラキラ', 'さ', 'せ', 'て', 'い', 'まし', 'た', '。', '\u3000', '豊富', 'な', '種類', 'の', '中', 'から', '、', 'どの', 'タイツ', 'を', '履い', 'たら', 'いい', 'の', 'か', '迷っ', 'ちゃう', 'の', 'も', '楽しみ', 'の', '一つ', '。', '履く', 'だけ', 'で', '気分', 'が', 'あがる', 'オシャレ', 'な', 'エフィング', 'の', 'タイツ', 'で', '、', 'あなた', 'は', 'セクシー', 'に', 'キメル', '？', '\u3000', 'キュート', 'に', 'キメル', '？']
#
# tag: t175
# pred_cat: movie-enter
# real_cat: movie-enter
# words:['『', 'アメイジング・スパイダーマン', '』', '新', '予告', 'が', '全世界', 'で', '解禁', '\u3000', '6月30日', 'の', '日本', 'で', 'の', '世界最速公開', 'に', '先駆け', 'て', '（', '全世界', '同時', '公開', 'は', '7月3日', '）', '、', '昨日', '7日', 'に', '日本', 'を', '含む', '世界', '11', 'ヶ国', '13', '都市', 'で', '先行', 'イベント', '「', 'THE', 'UNTOLD', 'STORY', '」', 'を', '開催', 'し', 'た', '映画', '『', 'アメイジング・スパイダーマン', '』', '。', '同', 'イベント', 'で', '3D', '上映', 'さ', 'れ', 'た', '第2弾', 'と', 'なる', '予告編', 'が', '全世界', 'で', '解禁', 'と', 'なっ', 'た', '。', '\u3000', '今回', '、', '解禁', 'さ', 'れ', 'た', '新', '予告', 'で', 'は', '、', 'アンドリュー・ガーフィールド', '演じる', 'スパイダーマン', '＝', 'ピーター・パーカー', 'の', '抱える', '孤独', 'と', '秘密', '、', 'そして', 'エマ・ストーン', '演じる', '新', 'ヒロイン', 'の', 'グウェン・ステーシー', 'と', 'の', '出会い', '、', 'ピーター', 'が', '思い出', 'で', 'しか', '知ら', 'ない', '両親', 'の', '秘密', 'を', '知る', 'リース・イーヴァンズ', '演じる', '科学者', 'カート', '・', 'コナーズ', '博士', '、', '悪役', 'で', 'も', 'ある', '謎', 'の', '“', 'リザード', '”', 'の', '全容', 'など', '、', '本作', 'で', '重要', 'な', '意味', 'を', '持つ', 'で', 'あろ', 'う', 'キャラクター', 'が', '、', 'より', '深く', '語ら', 'れ', 'て', 'いる', '。', '・', 'アメイジング・スパイダーマン', '-', '公式サイト']
#
# tag: t4437
# pred_cat: peachy
# real_cat: peachy
# words:['しっかり', '食べ', 'て', '痩せ', 'られる', '「', '糖質オフダイエット', '」', 'ダイエット', 'と', 'いえ', 'ば', '、', '食欲', 'と', 'の', '戦い', '。', '「', '食べ', 'なけれ', 'ば', '痩せる', '」', 'と', '勘違い', 'し', 'て', '、', '辛い', '食事制限', 'を', 'し', 'て', 'は', 'い', 'ませ', 'ん', 'か', '？', '今回', 'ご', '紹介', 'する', '「', '糖質オフダイエット', '」', 'は', '、', '「', 'ダイエット', '中', 'だ', 'けど', '、', 'ご飯', 'は', 'しっかり', '食べ', 'たい', '！', '」', 'という', '欲張り', '女子', 'に', 'オススメ', 'し', 'たい', 'レシピアプリ', 'です', '。', 'この', 'アプリ', 'に', 'は', '、', 'カロリー', 'や', '運動', 'を', '気', 'に', 'せ', 'ず', 'に', 'お肉', 'も', 'たくさん', '食べ', 'られる', '“', 'おいしい', '”', 'レシピ', 'を', '55点', '掲載', '。', '栄養', 'バランス', 'も', 'バッチリ', 'な', 'レシピ', 'ばかり', 'な', 'ので', '、', '代謝', 'を', 'よく', 'し', 'たり', '、', 'お', '肌', 'が', '元気', 'に', 'なっ', 'たり', 'と', '、', '美容', 'に', 'も', '効果', '的', 'です', '。', 'レシピ', '以外', 'に', 'も', '、', '・', '中医学', '理論', 'に', '基づい', 'た', '『', '糖質オフダイエット', '体質', '診断', '』', '・', 'あなた', 'の', 'ダイエット', 'を', 'サポート', 'する', '『', '糖質オフダイエット', 'コラム', '』', '・', 'どんな', '食材', 'が', '良い', 'の', 'か', 'わかる', '『', '糖質', 'オフ', '薬膳', '食材', '辞典', '』', '・', '料理', '中', 'でも', 'レシピ', 'ページ', 'が', '消え', 'ない', '『', 'スリープオフ', '機能', '』', '・', '調理', 'を', 'サポート', '『', 'キッチンタイマー', '』', 'など', 'の', '便利', 'な', 'コンテンツ', 'が', '充実', 'し', 'て', 'いる', 'の', 'も', '嬉しい', 'ポイント', '。', 'さらに', '、', '特別', '記念', 'セール', 'として', '通常', '250円', 'の', '提供', '価格', 'が', '66', '％', 'オフ', 'の', '85円', 'で', '購入', 'できる', 'キャンペーン', 'を', '3月30日', 'まで', '実施', '！', '多く', 'の', '雑誌', 'など', 'で', 'も', '特集', 'が', '組ま', 'れ', 'て', 'いる', '注目', 'の', 'ダイエット', '法', 'で', '、', '不健康', 'で', '続か', 'ない', 'ダイエット', 'に', 'サヨナラ', 'し', 'て', 'み', 'て', 'は', '？', '■', 'アプリ', '概要', 'アプリ', '名', '：', '糖質オフダイエット', '配信', '開始', '日', '：', '2012年', '3月23日', '（', '金', '）', '提供', '価格', '：', '250円', '（', '税込', '）\u3000⇒', '3/3', '0', 'まで', '85円', 'カテゴリ', '：', 'ヘルスケア', '/', 'フィットネス', '提供', 'ストア', '：', 'App Store', '対応', '端末', '：', 'iPhone 3GS', ',', 'iPhone 4', ',', 'iPhone 4S', '■', '関連', 'サイト', '「', '糖質オフダイエット', '」', 'ダウンロード', 'ページ']
#
# tag: t6485
# pred_cat: smax
# real_cat: smax
# words:['NTTドコモ', '、', '2012年', '3月', '期', '決算説明会', 'を', '開催', '！', '今夏', 'モデル', 'は', '5月中旬', 'に', '発表', '予定', 'で', 'スマホ', 'は', '7割', 'が', 'Xi', '対応', 'へ', 'らくらくスマートフォン', 'も', '登場', '予定', '！', 'NTTドコモ', 'は', '27日', '、', '2011年', '3月', '期', '（', '2011年', '4月', '〜', '2012年', '3月', '）', '決算説明会', 'を', '開催', 'し', '、', 'その', '中', 'で', '、', '5月中旬', 'に', '「', '2012年', '夏モデル', '」', 'の', '発表会', 'を', '開催', 'する', '方針', 'を', '明らか', 'に', 'し', 'て', 'い', 'ます', '。', 'また', '、', '今夏', 'モデル', 'の', 'スマートフォン', 'の', 'うち', '約', '7割', 'が', '高速', 'データ通信', '規格', 'LTE', 'に', '対応', 'し', 'た', '「', 'Xi', '（', 'クロッシィ', '）', '」', 'に', '対応', 'する', 'こと', '、', 'らくらくホン', 'を', '継承', 'し', 'た', 'らくらくスマートフォン', 'を', '投入', 'する', 'こと', 'を', '示し', '、', 'スマートフォン', 'の', 'さら', 'なる', 'ラインナップ', '拡充', 'を', 'する', 'と', 'し', 'て', 'い', 'ます', '。', '登壇', 'し', 'た', 'NTTドコモ', '代表取締役社長', 'の', '山田隆', '持氏', '（', '右', '画像', '）', 'は', '、', '2012年度', 'の', '目標', 'の', '中', 'で', '中心', 'に', 'なる', 'の', 'が', 'スマートフォン', '・', 'Xi', '販売', 'の', '促進', 'だ', 'と', 'し', '、', '2011年度', '末', '（', '2012年', '3月', '末', '）', '時点', 'で', '222', '万', '件', 'の', '契約', 'で', 'ある', 'Xi', 'について', '2012年度', '末', '（', '2013年', '3月', '末', '）', 'まで', 'に', '1000万', '契約', '以上', 'を', 'めざす', 'こと', '説明', 'し', 'まし', 'た', '。', '山田', '社長', 'そのため', 'に', 'スマートフォン', 'や', 'Xi', '対応', '機器', 'の', 'ラインナップ', 'を', 'さらに', '拡充', 'し', 'て', 'いく', '予定', 'で', '、', '近日', 'また', '詳細', 'を', '説明', 'する', 'と', 'し', '、', '2012年', '夏モデル', 'を', '5月中旬', 'に', '発表', 'する', 'こと', 'を', '示し', 'まし', 'た', '。', 'この', '今夏', 'モデル', 'の', 'スマートフォン', 'の', 'うち', '約', '7割', 'が', 'Xi', 'に', '対応', 'し', 'て', 'おり', '、', 'らくらくホン', 'を', '継承', 'する', '「', 'らくらくスマートフォン', '」', 'も', '投入', '予定', 'で', 'ある', 'こと', 'が', '説明', 'さ', 'れ', 'まし', 'た', '。', 'ただし', '、', '夏モデル', 'だけ', 'で', 'は', 'なく', '2012年度', '通期', 'で', '見れ', 'ば', 'Xi', '対応', 'スマートフォン', 'は', '約', '6割', 'に', 'なる', 'と', 'いう', '。', '2011年度', 'は', '前年度', '（', '2010年度', '）', '比', '約', '3.5倍', 'と', 'なる', '882', '万', '台', 'の', 'スマートフォン', 'を', '販売', 'し', '、', '全', '販売台数', 'の', '2209', '万', '台', 'の', 'うち', '約', '4割', 'を', '占め', 'た', 'こと', 'を', '説明', '。', '2012年度', 'は', 'さらに', '前', '販売台数', '目標', '2380', '万', '台', '、', 'この', 'うち', 'スマートフォン', '販売台数', '目標', '1300', '万', '台', 'と', 'およそ', '55', '％', 'と', '5割', 'を', '超える', '状況', 'に', 'なる', 'と', '予測', 'し', 'て', 'いる', 'と', 'の', 'こと', '。', 'スマートフォン', 'の', '比率', 'が', '半分', 'を', '超える', 'こと', 'に', 'なり', '、', '今後', 'は', '、', '従来', 'の', 'ケータイ', '（', 'フィーチャーフォン', '）', 'は', 'キッズケータイ', 'など', 'の', 'よう', 'な', '特殊', 'な', 'モデル', 'のみ', 'に', 'なる', 'という', 'こと', 'です', '。', 'Xi', 'について', 'も', '一部地域', 'で', 'は', '1', '.', '5', 'GHz', '帯', 'を', '使用', 'し', 'て', '下り', '最大', '115', '.', '2', 'Mbps', 'の', 'サービス', 'を', '2012年度', '中', 'に', '提供開始', '予定', 'で', 'ある', 'こと', 'も', '示さ', 'れ', 'まし', 'た', '。', 'この', '他', '、', '競合', 'と', 'なる', '他社', 'が', '販売', 'する', 'iPhone', 'シリーズ', 'で', 'も', '実質', '1', '万', '程度', 'で', 'ある', 'こと', 'を', '挙げ', '、', '2012年度', 'は', '競合', 'と', 'の', '競争力', 'を', '付ける', 'ため', 'に', '現在', 'の', '実質', '価格', '2万円', '〜', '2', '万', '5000円', '程度', 'を', '実質', '価格', '1万円', '〜', '1', '万', '5000円', '程度', 'に', '下げ', '、', '端末', '価格', 'を', '月額', '利用', '料', 'から', '割り引く', '施策', '「', '月々', 'サポート', '」', 'を', 'これ', 'まで', 'より', 'も', '増額', 'さ', 'せ', 'て', 'いく', '方針', 'で', 'ある', 'こと', 'を', '示し', 'て', 'い', 'まし', 'た', '。', '記事', '執筆', '：', 'memn0ck']
#
# tag: t5681
# pred_cat: dokujo-tsushin
# real_cat: dokujo-tsushin
# words:['『', '結婚', '』', 'より', 'も', '『', '結婚生活', '』', 'を', '続ける', '方', 'が', '難しい', '…', '!?\u3000', 'Presented', 'by', 'ゆるっ', 'と', 'Cafe', 'あんなに', '好き', 'で', '結婚', 'し', 'た', 'のに', '、', 'なんで', 'こう', 'なっ', 'ちゃう', 'の', '？', '結婚', 'し', 'た', '時', 'は', 'ラブラブ', 'でも', '、', '結婚生活', 'を', '何', '年', 'か', 'おくる', 'と', 'やって来る', '倦怠期', '。', 'しょせん', '、', '違う', '親', 'の', '元', 'で', 'まったく', '異なる', '環境', 'で', '育っ', 'た', '二人', 'だ', 'もん', '。', '惚れ', 'て', '腫れ', 'て', '夫婦', 'に', 'なっ', 'た', 'から', 'と', 'いっ', 'て', '、', 'すべて', 'が', '上手く', '合致', 'する', 'ほう', 'が', '奇跡', 'な', 'の', 'よ', 'ね', '。', 'そもそも', '付き合っ', 'てる', '時', 'って', '彼', 'の', 'いい', '部分', 'ばかり', 'を', '見', 'て', 'いる', '訳', 'で', '、', '結婚', 'し', 'て', '一緒に', '暮らし', 'て', 'みる', 'と', '、', '今', 'まで', '見え', 'なかっ', 'た', '部分', 'まで', '見え', 'て', 'くる', '。', '例えば', '、', '「', '湯船', 'に', '入る', '前', 'に', '体', 'を', '洗う', 'の', 'は', '常識', 'じゃ', 'ない', 'の', '？', '」', 'とか', '、', '「', '寝る', '前', 'に', 'なんで', '歯', 'を', '磨か', 'ない', 'の', '？', '」', 'と', 'か', '。', '恋愛', '中', 'は', '気', 'に', 'なら', 'なかっ', 'た', 'こと', 'も', '、', '結婚', 'し', 'て', '共に', '生活', 'する', 'うち', 'に', '、', 'だんだん', 'イラッと', 'くる', 'もん', 'な', 'の', 'よ', '。', 'だって', 'きれいな', '髪の毛', 'も', '、', '洗面所', 'に', '落ちれ', 'ば', '一瞬', 'に', 'し', 'て', '汚い', 'ゴミ', 'だ', 'もん', 'ね', '。', '結婚', 'で', '大事', 'な', 'こと', '、', 'それ', 'って', 'スピーチ', 'で', '使い古さ', 'れ', 'た', '3つ', 'の', '袋', 'なんか', 'じゃ', 'ない', 'って', '思う', 'ん', 'だ', 'よ', 'ね', '。', '相手', 'と', 'の', '同化', 'を', '求める', 'ん', 'で', 'は', 'なく', '、', 'お互い', 'の', '『', '違い', '』', 'を', '理解', 'し', 'て', '受け入れる', 'こと', 'な', 'ん', 'だ', 'と', '思う', '。', 'だって', '許容', 'の', 'プライオリティー', 'って', '人', 'それぞれ', 'じゃ', 'ない', '？', 'ダンナ', 'の', '風俗', '遊び', 'くらい', 'なら', 'OK', 'という', '人', 'も', 'いれ', 'ば', '、', '借金', 'は', 'いい', 'けど', '風俗', 'は', '絶対', 'ダメ', '！', 'っていう', '人', 'も', 'いる', 'でしょ', '？', '\u3000', '一番', '重要', 'な', 'の', 'は', '『', 'お互い', 'の', '違い', 'を', '理解', 'する', '』', 'って', 'こと', 'な', 'ん', 'だ', 'よ', 'ね', '。', 'だから', '一方', 'だけ', 'が', '、', '我慢', 'の', '連続', 'だ', 'と', '人間関係', 'って', '破綻', 'する', 'ん', 'だ', 'わ', '。', 'ある', '一人', 'の', 'ダンナ', 'が', '存在', 'する', '。', '強烈', 'な', 'モラハラ', '暴言', 'Ｄ', 'Ｖ', '夫', 'だ', '。', 'ここに', '描か', 'れ', 'て', 'いる', '夫婦', 'は', '対等', 'で', 'は', 'ない', '、', '妻', 'に', 'は', '人権', 'が', 'ない', 'の', 'だ', '。', '夫', 'に', '感謝', 'こそ', 'すれ', '、', '文句', 'を', '言う', 'な', 'と', '妻', 'を', '徹底的', 'に', '支配', 'する', '。', '史上', '最悪', '最低', 'の', '男', 'だ', '。', '人間', 'って', '全否定', 'さ', 'れ', '続ける', 'と', '、', 'だんだん', '自分', 'が', '悪い', 'ん', 'だ', '、', 'ダメ', 'な', 'の', 'は', '私', 'な', 'ん', 'だって', '自己否定', 'スパイラル', 'に', '陥っ', 'て', 'しまう', '。', 'これ', 'は', 'まさしく', 'その', '典型', '。', '毎日', 'ライフ', 'が', 'ゼロ', 'に', 'なる', 'まで', 'フルボッコ', 'さ', 'れる', '。', 'あー', 'もう', '、', 'この', 'ダンナ', '、', '本気', 'で', 'ムカ', 'つき', 'ます', '。', '一方', '、', 'もう', '一人', 'の', '問題', 'ある', 'ダンナ', 'は', '、', '1日', '中', '携帯', 'を', 'いじり', '、', 'プロレス', 'が', '大好き', 'で', '、', '足', 'は', '水虫', 'だらけ', 'の', '金', 'の', 'ない', 'ウザ', '男', 'だ', '。', 'お', '風呂', 'の', '前', 'に', '全裸', 'で', '踊る', 'の', 'が', '日課', 'だっ', 'たり', '、', '息子', '用', 'の', 'アイス', 'を', '隠れ', '食い', 'する', '馬鹿', 'ダンナ', '。', 'なんで', 'こんな', 'ダンナ', 'と', '結婚', 'し', 'て', 'しまっ', 'た', 'ん', 'だろ', 'う', 'って', '思っ', 'て', 'も', '後の祭り', '。', 'あー', '薬', 'を', '盛っ', 'て', '葬り', 'たい', '！', 'と', '思わ', 'ず', 'に', 'は', 'い', 'られ', 'ない', '。', 'よく', '「', '理想の結婚', '」', 'なんて', '安易', 'に', '語ら', 'れる', 'けども', '、', 'カップル', 'の', '数', 'だけ', '結婚', 'の', 'カタチ', 'が', 'ある', '。', '幸せ', 'という', 'もの', 'は', '『', '満足', '』', 'する', 'こと', 'な', 'の', 'だ', '。', '自分', 'の', '結婚', '観', 'を', '再確認', 'し', 'たい', 'あなた', '、', 'これから', '結婚', 'を', '控え', 'てる', 'あなた', 'に', '、', 'ぜひとも', '読ん', 'で', 'ほしい', '2', '冊', 'な', 'の', 'です', '。', '今回', '紹介', 'し', 'た', '2', '冊', 'は', 'WEBサイト', '「', 'ゆるっ', 'と', 'Cafe', '」', 'で', 'も', '閲覧', '可能', 'です', '。', '今回', '紹介', 'し', 'た', '2', '冊', 'は', 'WEBサイト', '「', 'ゆるっ', 'と', 'Cafe', '」', 'で', 'も', '閲覧', '可能', 'です', '。', '・', '『', '旦那', 'に', '薬', 'を', '盛り', 'まし', 'た', '』', '\u3000', '著', '・', '森野いずみ', 'ゆるっ', 'と', 'Cafe', '/', '竹書房', '刊', '・', '『', 'オレ', 'に', 'あやまれ', '!!', '史上', '最悪', '暴言', 'DV', '夫', 'と', 'の', '涙', 'の', '7年間 ...
#
# tag: t4914
# pred_cat: sports-watch
# real_cat: sports-watch
# words:['【', 'Sports', 'Watch', '】', '元', 'プロ野球選手', 'の', '大晦日', '格闘技', '参戦', 'に', '、', '松坂', 'と', '上原', 'が', 'コメント', '横浜ベイスターズ', '、', 'オリックス・バファローズ', 'に', '所属', 'し', 'た', '元', 'プロ野球選手', '・', '古木克明', 'が', '大晦日', 'の', '格闘技', 'イベント', '「', 'Dynamite!!', '」', 'において', '、', '格闘家', 'デビュー', 'を', '果たす', 'こと', 'に', 'なっ', 'た', '。', '30日', '深夜', '、', 'TBS', 'で', '「', '大晦日', 'は', 'ダイナマイト', '決戦', 'まで', 'あと', '20時間', 'SP', '」', 'が', '放送', 'さ', 'れる', 'と', '、', '番組', 'の', 'インタビュー', 'に対して', '、', '「', '正直', '、', '野球', 'に', 'も', '実力', 'の', '限界', 'を', '感じ', 'て', 'い', 'た', '。', '僕', 'にとって', 'は', '厳しい', 'かも', 'しれ', 'ない', 'です', 'けど', '、', 'いい', '選択', '。', '自分', 'の', '持ち味', 'を', '活か', 'せる', 'ところ', 'で', 'やっ', 'て', 'み', 'たい', '」', 'と', '古木', 'は', '語っ', 'た', '。', 'また', '、', '同', '番組内', 'で', 'は', '、', '松坂大輔', 'や', '上原浩治', 'ら', 'も', '、', '古木', 'に', 'コメント', 'を', '寄せる', '。', '「', 'カッチャン', 'の', 'こと', '知っ', 'てる', '野球ファン', 'も', '楽しみ', 'に', 'し', 'て', 'いる', 'と', '思い', 'ます', 'し', '、', 'その', '期待', 'を', '背負っ', 'て', '戦う', 'の', 'は', '簡単', 'な', 'こと', 'で', 'は', 'ない', '、', '難しい', 'こと', 'だ', 'と', '思い', 'ます', 'けど', '、', 'カッチャン', 'なら', 'やれる', 'と', '思い', 'ます', '」', 'という', '松坂', 'に', '、', '上原', 'は', '「', 'そういう', '舞台', 'に', '立てる', '人', 'って', '少ない', 'と', '思う', 'ので', '、', '思い切っ', 'て', 'やっ', 'て', 'ほしい', 'な', '。', '野球選手', 'が', 'どこ', 'まで', '通用', 'する', 'か', '、', 'すごい', '期待', 'し', 'て', 'い', 'ます', '」', 'と', '語っ', 'た', '。', '・', '海外', '格闘技', '情報', 'へ', '-', 'MMAPLANET', '・', '国内', '格闘技', '情報', '-', 'FIGHTISLANDS']
#
# tag: t3514
# pred_cat: livedoor-homme
# real_cat: livedoor-homme
# words:['【', 'Office', 'Scope', 'vol', '.', '08', '】', 'オシャレ', 'で', 'ポップ', 'な', '空間', 'が', '、', 'オフィス', 'を', '「', '楽しく', '仕事', 'を', 'する', '」', '場所', 'に', '（', '株式会社', 'Stardust', 'Communication', 's', '）', '\u3000', 'ワークスペース', 'の', 'デザイニング', 'に', '優れ', 'た', '企業', 'の', 'オフィス', 'を', '訪問', 'し', '、', 'そこで', '働く', '人々', 'の', '声', 'から', '、', 'その', '“', '働き', '心地', '”', 'を', 'リポート', 'する', '連載', '企画', '『', 'Office', 'Scope', '』', '。', '第', '8回', 'の', '今回', 'は', '、', '日本', '最大級', 'の', 'ケータイ', 'フリーマーケット', 'サイト', '『', 'ショッピーズ', '』', 'の', '運営', 'を', '手がける', '、', '株式会社', 'Stardust', 'Communication', 's', 'を', 'ご', '紹介', '。', 'トレンド', 'の', '最先端', 'を', '行く', '女子', '中高生', 'たち', 'から', '絶大', 'な', '支持', 'を', '集める', 'IT', 'ベンチャー', 'が', '目指す', '理想', '型', 'の', 'オフィス', 'と', 'は', '!?', 'エントランス', 'の', '両サイド', 'に', 'も', 'さながら', 'ジブリ', '映画', 'の', 'よう', 'な', '光景', 'が', '。', '奥', 'の', 'トビラ', 'の', '向こう', 'は', '会議室', '。', '正面', 'に', 'は', '役員', '室', '。', '左手', 'の', 'ドア', 'の', '向こう', 'に', 'は', '多目的', 'に', '使える', 'リフレッシュ', 'スペース', 'が', '広がっ', 'て', 'いる', '。', '木目調', 'の', 'ドア', 'を', '開ける', 'と', '、', '白', 'を', '基調', 'に', 'し', 'た', 'シンプル', 'で', 'こじんまり', 'と', 'し', 'た', '会議室', 'が', '現れる', '。', '社員', 'の', 'モチベーション', 'を', '第一', 'に', '考え', 'た', 'オフィス', 'デザイン', '\u3000', '「', '僕', '個人', 'は', '特に', 'こだわり', 'が', 'ある', 'ほう', 'で', 'も', 'ない', 'ので', '、', 'オフィス', 'を', '移転', 'する', '際', 'も', '、', '当初', 'は', '『', '広', 'さ', 'さえ', 'あれ', 'ば', '』', 'ぐらい', 'に', 'しか', '考え', 'て', 'い', 'なかっ', 'た', 'ん', 'です', '。', 'だから', '、', 'デザイン', 'を', '『', 'ヴィス', '』', 'さん', 'に', 'お願い', 'し', 'た', 'の', 'も', '、', '『', 'こう', 'し', 'たい', '』', 'っていう', '主体', '的', 'な', 'イメージ', 'が', 'あっ', 'た', 'と', 'いう', 'より', 'は', '、', '社員', 'の', 'モチベーション', 'に', 'つながる', 'の', 'なら', '、', 'オフィス', 'に', 'リソース', 'を', '割い', 'て', 'みる', 'の', 'も', 'いい', 'かなっ', 'て', 'ぐらい', 'の', 'トライアル', '感覚', '。', 'ウチ', 'の', 'メイン', 'ユーザー', 'は', '女子', '中高生', 'です', 'し', '、', '社内', 'に', 'は', '若い', '女性社員', 'も', '多く', 'いる', 'ので', '、', 'スタイリッシュ', 'で', 'は', 'あり', 'つつ', '、', 'ポップ', 'さ', 'も', '感じ', 'て', 'もらえれ', 'ば', 'って', 'こと', 'で', '現在', 'の', 'よう', 'な', 'カタチ', 'に', 'なっ', 'た', 'ん', 'です', '」', '\u3000', 'そう', '語る', '代表取締役社長', 'の', '井上氏', 'ら', '、', '3人', 'の', '設立', 'メンバー', 'と', '1', '〜', '2', '名', 'の', 'アルバイト', 'のみ', 'で', 'スタート', 'し', 'た', '株式会社', 'Stardust', 'Communication', 's', 'は', '、', 'この', '9月', 'で', '設立', '5周年', '。', 'ケータイ', 'ひとつ', 'で', '女子', '中高生', 'を', '中心', 'と', 'する', '60万人', '以上', 'の', 'ユーザー', 'が', '、', '190万', '点', 'も', 'の', '商品', 'を', '自由', 'に', 'やりとり', 'できる', '、', '日本', '最大級', 'の', 'フリーマーケット', 'サイト', '『', 'ショッピーズ', '』', 'を', 'はじめ', 'と', 'し', 'た', 'モバイル', 'メディア', 'の', '運営', 'を', '数々', '手がける', '同社', 'は', '、', '多様', 'な', 'IT', '業界', 'の', 'なか', 'で', 'も', 'いま', '最も', '勢い', 'の', 'ある', 'ベンチャー企業', 'の', 'ひとつ', 'だ', '。', '調', '光', 'によって', 'バー', 'ラウンジ', 'の', 'よう', 'な', '雰囲気', 'に', 'なる', 'リフレッシュ', 'スペース', '。', '夜', '8時', '以降', 'は', 'なんと', 'お酒', 'も', '飲み放題', '。', 'リフレッシュ', 'スペース', 'で', 'は', 'ユーザー', 'を', '招い', 'た', '座談会', 'も', '開催', '\u3000', '「', 'オフィス', 'を', '作る', 'にあたって', '、', '僕', 'が', '目指し', 'た', 'の', 'は', '『', '広', 'さ', '』', 'と', '『', '快適', 'さ', '』', '、', 'それに', '『', 'ユーザー', 'が', '気軽', 'に', '足', 'を', '運べる', '空間', 'で', 'ある', 'こと', '』', 'の', '3つ', '。', 'トップダウン', 'で', 'やっ', 'て', 'み', 'て', '使っ', 'て', 'もらえ', 'なかっ', 'たら', '悲しい', 'な', '、', 'なんて', '危惧し', 'たり', 'も', 'し', 'て', 'は', 'いたん', 'です', 'が', '、', 'そこ', 'は', '自然', 'と', '社内', '文化', 'として', '浸透', 'し', 'て', 'くれ', 'た', 'と', '思い', 'ます', '。', '十分', 'な', '広', 'さ', 'を', '確保', 'し', 'た', 'リフレッシュ', 'スペース', 'は', '、', '会社説明会', 'や', '勉強会', 'は', 'もちろん', '、', '社員', 'たち', 'の', '誕生', '会', 'や', '歓迎会', 'に', 'も', '活用', 'さ', 'れ', 'て', 'い', 'ます', 'し', '、', 'ワーク', 'スタイル', 'という', '面', 'で', 'も', '期待', '通り', 'の', 'シナジー', 'は', '起こせ', 'てる', 'ん', 'じゃ', 'ない', 'か', 'な', '、', 'と', '」', '\u3000', '来客', '用', 'の', '応接', 'スペース', 'で', 'ある', 'と', '同時に', '、', '社員', '同士', 'が', '気軽', 'に', '親睦', 'を', '深め', 'られる', '場所', 'として', 'も', '公私', 'の', '別', 'なく', '有効活用', 'さ', 'れ', 'て', 'いる', 'リフレッシュ', 'スペース', 'で', 'は', '、', 'サイト', 'を', '利用', 'する', '実際', 'の', 'ユーザー',  ...
#
# tag: t3500
# pred_cat: livedoor-homme
# real_cat: livedoor-homme
# words:['優しい', '上司', 'は', '優柔不断', '！', '？', '\u3000', '〜', '「', '判断', '」', '「', '指示', 'する', '」', 'という', 'こと', '〜', '｜', '実践', '！', '問題解決', '力', 'テスト', '【', '第', '1', '問', '】', '港', '君', 'は', '最近', '悩ん', 'で', 'い', 'ます', '。', '直属', 'の', '上司', 'で', 'ある', '加藤', '課長', 'の', 'こと', 'です', '。', '加藤', '課長', 'は', '港', '君', 'を', '可愛がっ', 'て', 'おり', '、', '一緒', 'に', '飲み', 'に', '行く', 'こと', 'も', '多く', '、', '意見', 'を', '聞い', 'て', 'くれる', '優しい', '上司', 'です', '。', 'しかし', '、', '港', '君', 'を', 'はじめ', 'と', 'する', '部下', 'の', '意見', '、', '部長', 'の', '意見', 'によって', '自分', 'の', '意見', 'を', 'すぐ', 'に', '変え', 'て', 'しまう', '困っ', 'た', 'ところ', 'が', 'ある', 'の', 'です', '。', 'つい', '先日', 'も', '、', 'こんな', 'こと', 'が', 'あり', 'まし', 'た', '。', '加藤', '課長', 'が', '部長', 'の', '部屋', 'から', '戻っ', 'て', 'き', 'た', '後', '、', 'こう', 'いっ', 'た', 'の', 'です', '。', '「', '部長', 'から', '今期', 'の', '売上', 'は', '前期', 'の', '150', '％', '増', 'と', '目標', 'を', '言い渡さ', 'れ', 'た', '。', 'ここ', 'で', '達成', 'できる', 'か', 'が', '会社', 'の', '大きな', '岐路', 'と', 'なる', '。', '絶対', 'みんな', 'で', '達成', 'しよう', '！', 'そのため', 'に', 'は', '、', '社内', 'の', '規則', 'など', 'も', '柔軟', 'に', '見直す', 'と', '言っ', 'て', 'くださっ', 'た', '。', '何', 'か', '変更', 'し', 'たい', '部分', 'が', 'ある', '者', 'は', '、', '遠慮なく', '言っ', 'て', 'くれ', '！', '」', 'そこ', 'で', '一番', 'に', '手', 'を', '上げ', 'た', 'の', 'が', '、', '片山', '君', '。', '「', '月末', 'の', '申込', '書', 'を', 'もらっ', 'て', 'くる', '締め切り', 'を', '延ばし', 'て', '欲しい', 'です', '！', 'そう', 'すれ', 'ば', '月', 'あたり', 'の', '売上', 'も', '上がる', 'し', '、', '会社', 'も', 'ハッピー', 'です', 'よ', 'ね', '！', '」', '加藤', '課長', 'は', '大', '賛成', '。', '「', 'そう', 'しよう', '！', '最終日', 'の', '20時', 'まで', '大丈夫', 'だろ', 'う', '。', '今月', 'から', 'そう', 'しよう', '！', '」', '実際', 'やっ', 'て', 'みる', 'と', '、', '現場', 'の', '営業', 'は', '遅く', 'まで', '営業活動', 'を', '行わ', 'なけれ', 'ば', 'なら', 'なく', 'なり', '、', '不満の声', 'が', '。', 'その', 'こと', 'を', '港', '君', 'が', '加藤', '課長', 'に', '伝える', 'と', '、', '「', 'そっか', '。', 'なら', 'ば', '定時', 'の', '18時', 'まで', 'と', 'しよう', '！', '」', 'と', '変更', '。', 'すると', '翌月', 'は', '、', '20時', 'まで', 'と', '思っ', 'て', 'い', 'た', '社員', 'は', '、', '18時', 'を', '過ぎ', 'て', 'も', '帰社', 'せ', 'ず', '、', '経理', 'も', '申込', '書', 'の', '精算', 'が', '出来', 'ず', '、', '社内', 'は', '大', '混乱', '。', '加藤', '課長', 'は', '部長', 'に', '呼び出さ', 'れ', '、', 'こう', '言わ', 'れ', 'た', 'の', 'です', '。', '「', '経理', 'の', '精算', 'は', '最終日', '中', 'に', '報告', 'せ', 'ね', 'ば', 'なら', 'ん', 'の', 'だ', '！', '経理部', 'は', '徹夜', 'で', '対応', 'しろ', 'と', 'いう', 'の', 'か', '！', 'しっかり', '考え', 'て', '施策', 'を', 'しろ', '。', '社内', '規則', 'を', '変え', 'て', 'も', 'いい', 'と', 'は', '言っ', 'た', 'が', '、', '他', '部署', 'に', '迷惑', 'かけ', 'て', 'も', 'いい', 'と', 'は', '言っ', 'て', 'ない', 'ぞ', '。', '」', 'と', 'の', 'こと', '。', '結局', '、', '今', 'まで', '通り', 'の', '15時', 'まで', 'という', 'ルール', 'に', '戻っ', 'た', 'の', 'です', '。', '港', '君', 'は', 'たまりかね', 'て', 'しまい', 'まし', 'た', '。', '「', 'ちゃんと', '結論', 'を', '出して', 'から', '指示', 'し', 'て', 'ください', '！', '」', '【', '質問', '】', '加藤', '課長', 'は', 'どの', 'よう', 'に', '行動', 'す', 'べき', 'だっ', 'た', 'と', '考え', 'ます', 'か', '？', '1', '.', 'コロコロ', '変わる', 'と', '現場', 'が', '混乱', 'する', '。', 'しばらく', '経過', 'を', '見守る', 'べき', 'だっ', 'た', '2', '.', '部長', 'の', '指示', 'の', '出し', '方', 'が', '曖昧', 'だっ', 'た', '。', '加藤', '課長', 'は', '悪く', 'ない', '3', '.', 'もっと', '広い', '視野', 'を', '持っ', 'て', '対応', 'を', '考える', 'べき', 'だっ', 'た', '4', '.', 'ときには', '臨機応変', 'な', '対応', 'も', '必要', '。', '加藤', '課長', 'の', '行動', 'は', '正しかっ', 'た', '1', '2']
#
# tag: t1825
# pred_cat: kaden-channel
# real_cat: kaden-channel
# words:['猛暑', 'で', 'ダメージ', 'を', '受け', 'た', '肌', 'に', '！', 'ヤーマン', 'から', '温冷', 'ケア', '美顔機', '新', '発売', '【', '売れ筋', 'チェック', '】', '猛暑', 'が', '続き', '、', '毎日', '熱中症', 'の', 'ニュース', 'が', '伝え', 'られ', 'て', 'いる', '。', '熱帯夜', 'で', '寝不足', 'だっ', 'たり', '、', '節電', 'の', '影響', 'で', 'オフィス', 'で', 'も', '汗だく', 'に', 'なっ', 'たり', 'と', '、', '暑さ', 'の', 'せい', 'で', 'で', '肌', 'の', '調子', 'が', '悪い', 'という', '人', 'も', '多い', 'だろ', 'う', '。', '手遅れ', 'に', 'なら', 'ない', 'うち', 'に', '気持ち良く', 'セルフケア', 'を', 'し', 'たい', 'もの', 'だ', '。', 'ヤーマン', 'は', '温冷', 'ケア', 'が', '切り替え', 'なし', 'で', '同時に', 'できる', '美顔機', '、', '『', '温冷', 'プレート', '』', 'を', '直販', 'チャンネル', 'で', '8月3日', 'より', '新', '発売', 'する', '。', '\u3000', '■', '同時に', '使える', '温', '・', '冷', 'パッド', 'で', '肌', 'の', 'あらゆる', '悩み', 'の', '解決', 'へ', '肌', 'を', '温め', 'たり', '冷やし', 'たり', 'し', 'て', '肌', 'に', '温度', '差', 'を', '与える', 'と', '血行', 'が', '良く', 'なり', '、', '新陳代謝', 'が', '活発', 'に', 'なる', '。', '皮膚', 'の', 'ターンオーバー', 'が', '促進', 'さ', 'れ', '、', 'シミ', '、', 'シワ', '、', 'くすみ', '、', 'たるみ', 'といった', '老化', '現象', '、', 'ニキビ', '、', '血行', '不良', '、', '毛穴', 'の', '引き締め', '、', '美白', 'など', '肌', 'の', '悩み', 'の', '解決', 'に', 'つながる', '。', '本', '製品', 'の', '温', 'プレート', '、', '冷', 'プレート', 'の', '温度', '差', 'は', '最大', '30℃', '。', '約', '40℃', 'の', '温', 'プレート', 'で', '毛穴', 'を', '開き', '、', '美容', '成分', 'を', '奥', 'まで', '浸透', 'さ', 'せ', '約', '１０℃', 'まで', '冷える', '冷', 'プレート', 'で', '毛穴', 'を', '引き締める', '。', '電源', 'を', '入れる', 'と', '温', '・', '冷', 'どちら', 'の', 'パッド', 'も', '出力', 'を', '開始', 'する', 'ので', '、', '温冷', '同時に', '使える', '。', '■', '充電', '式', 'で', '持ち運び', 'に', '便利', '、', '使い', 'やすい', '形状', 'で', 'いつ', 'でも', 'どこ', 'でも', 'ケア', 'できる', '円形', '型', 'な', 'ので', '、', '目', 'の', '周り', 'や', '小鼻', 'の', '横', 'など', '気', 'に', 'なる', '顔', 'の', '細か', 'な', '部分', 'に', 'フィット', '。', 'また', '、', '握り', 'やすい', '形', 'で', '持ち運び', 'に', '便利', 'な', '充電', '式', 'な', 'ので', '、', 'いつ', 'でも', 'どこ', 'でも', 'ケア', 'できる', '。', 'さらに', '、', '12分', 'で', '温冷', '動作', 'が', '、', '14分', 'で', '電源', 'が', 'オートオフ', 'する', 'ので', '安心', 'だ', '。', '■', 'スペック', '商品名', '：', '温冷', 'プレート', '付属品', '：', 'ＡＣ', 'アダプター', '、', '取扱', '説明書', 'カラー', '・', '型番', '：', 'パールホワイト', '・', 'Ｈ', 'Ｂ', '‐', '７', '重量', '・', 'サイズ', '：', '約', '180', 'ｇ', '・', 'W', '46', 'xD', '27', 'xH', '175m', 'm', '価格', '：', '12', ',', '800円', '（', '税込', '）', '直販', 'チャンネル', '（', '牧田', '\u3000', '亜紀子', '）']
#
#
# === Wrong predictions ===
# tag: t4760
# pred_cat: it-life-hack
# real_cat: sports-watch
# words:['【', 'Sports', 'Watch', '／', '競馬', '】', '配当', '上乗せ', 'の', '「', 'JRAプレミアムレース', '」', 'で', 'は', 'この', '馬券', 'を', '買え', '！', '2月21日', '、', 'フェブラリーS', 'が', '行わ', 'れ', 'た', '後', 'の', '東京', '最終', 'レース', 'は', '「', '東京', 'ウインター', 'プレミアム', '」', 'と', '題さ', 'れ', 'た', 'JRAプレミアム', 'の', '対象', 'レース', 'だっ', 'た', '。', '2008年', 'から', 'スタート', 'し', 'た', 'JRAプレミアム', 'は', '、', '指定', 'さ', 'れ', 'た', 'レース', 'の', '配当', 'に', '売り上げ', 'の', '約', '5', '％', 'を', '上乗せ', 'する', 'という', 'もの', 'で', '、', '私達', 'ファン', 'は', '馬券', 'を', '的中', 'さ', 'せれ', 'ば', 'いつも', 'より', '高い', '配当', 'を', '手', 'に', 'する', 'こと', 'が', 'できる', 'わけ', 'だ', 'が', '、', 'この', 'レース', 'は', '7', '→', '9', '→', '1番人気', 'で', '決まり', '、', '馬連', '3', '万', '馬券', '、', '3連単', '36', '万', '馬券', 'という', '波乱', 'の', '結果', 'と', 'なっ', 'た', '。', 'この', 'レース', 'で', 'プレミアム', 'の', '恩恵', 'を', '受け', 'られ', 'た', '人', 'は', '、', '果たして', 'どれ', 'ほどい', 'た', 'だろ', 'う', 'か', '。', 'せっかく', 'の', 'プレミアム', 'レース', 'も', '、', '的中', 'さ', 'せ', 'なけれ', 'ば', '何', 'の', '意味', 'も', 'ない', '。', 'そして', '、', '馬券', 'の', '種類', 'や', '人気', 'によって', '配当', 'の', '上乗せ', '率', 'は', '上下', 'し', 'て', 'くる', 'ため', '、', '私達', 'は', 'その', 'あたり', 'も', '考慮', 'し', 'つつ', '馬券', 'を', '購入', 'する', '必要', 'が', 'ある', 'の', 'だ', '。', '単勝', '：', '5', '.', '22', '％', '\u3000', '複勝', '：', '4', '.', '75', '％', '\u3000', '\u3000', '枠連', '：', '6', '.', '31', '％', '\u3000', 'ワイド', '：', '6', '.', '26', '％', '馬連', '：', '6', '.', '62', '％', '\u3000', '馬単', '：', '6', '.', '69', '％', '\u3000', '3連複', '：', '6', '.', '71', '％', '\u3000', '3連単', '：', '6', '.', '79', '％', '上記', 'の', '数値', 'は', '2008年', 'から', '2010年', 'まで', 'の', 'JRAプレミアム', '対象', '全', 'レース', 'における', '、', '馬券', 'ごと', 'の', '配当', '上乗せ', '率', '平均', '値', 'で', 'ある', '。', '上乗せ', '率', 'を', '算出', 'する', '厳密', 'な', '計算', '式', 'の', '説明', 'は', '省く', 'が', '、', 'この', '数値', 'を', '基', 'に', 'プレミアム', 'レース', 'の', '恩恵', 'を', '確実', 'に', '受ける', 'ため', 'の', '馬券', '戦略', 'を', '探っ', 'て', 'いき', 'たい', '。', '・', 'ワイド', '、', '枠連', 'で', '確実', 'に', '配当', 'ゲット', '他', 'の', '馬券', 'に', '比べ', 'て', '的中率', 'の', '高い', 'ワイド', 'だ', 'が', '、', '配当', '上乗せ', '率', 'は', '他', 'の', '券種', 'と', 'ほとんど', '変わら', 'ない', '6', '％', '台', '。', 'レース', 'ごと', 'に', '生じる', '上乗せ', '率', 'の', '上下', '幅', 'も', 'それほど', 'ない', 'こと', 'から', '、', '確実', 'に', '的中', 'さ', 'せ', 'て', 'いつも', 'より', '多い', '払い戻し', 'を', '受け', 'た', 'い人', 'に', 'は', '一番', 'オススメ', 'の', '馬券', 'だ', '。', '枠連', 'も', '、', 'ワイド', 'と', 'それほど', '変わら', 'ない', '上乗せ', '率', '。', '狙い', '馬', 'が', '同', '枠', 'に', '入っ', 'た', '際', 'など', 'に', 'は', '積極的', 'に', '買い', 'たい', '。', '・', '複勝', 'は', '人気', '薄', 'を', '狙え', '上乗せ', '率', '平均', 'で', 'は', '4', '.', '75', '％', 'と', '低め', 'だ', 'が', '、', 'その', '上下', '幅', 'が', '0', '％', '〜', '11', '.', '9', '％', 'と', '、', 'レース', 'ごと', 'の', '上乗せ', '率', 'に', 'もっとも', 'バラ', 'つき', 'が', '見', 'られる', 'の', 'が', '複勝', '馬券', 'で', '、', '上乗せ', '率', 'は', '人気', 'が', '下がれ', 'ば', '下がる', 'ほど', '高く', 'なる', '傾向', 'に', 'ある', '。', '例えば', 'ウインター', 'プレミアム', 'で', '2着', 'に', '入っ', 'た', '9番人気', 'ヤマニンリュバン', 'の', '複勝', 'が', '80円', 'アップ', 'の', '980円', 'と', 'なっ', 'て', 'いる', 'よう', 'に', '、', '複勝', 'を', '買う', '際', 'に', 'は', '極力', '人気', '薄', 'を', '意識', 'し', 'て', '買う', 'と', 'いい', 'だろ', 'う', '。', '逆', 'に', '、', '人気', '馬', 'の', '複勝', 'は', '10円', 'の', '上積み', 'さえ', '期待', 'でき', 'ない', 'こと', 'も', 'ある', 'ので', '注意', 'が', '必要', 'だ', '。', '・', '穴', '党', 'なら', 'いつも', 'どおり', '3連単', '！', '3連単', 'で', 'の', '配当', '上乗せ', '率', 'は', '、', 'どんなに', '堅かろ', 'う', 'が', '荒れよ', 'う', 'が', '、', 'ほぼ', '全て', 'の', 'レース', 'において', '6', '.', '7', '〜', '6', '.', '8', '％', 'で', '推移', 'し', 'て', 'いる', '。', 'つまり', '5', ',', '000', '円', '前後', 'の', '配当', 'で', 'も', '10万', '馬券', 'で', 'も', '、', '確実', 'に', '上記', 'パーセンテージ', 'の', '上乗せ', 'が', '期待', 'できる', '。', 'ちなみに', 'ウインター', 'プレミアム', 'の', '3連単', '配当', 'は', '、', '366', ',', '690円', 'の', 'うち', '23', ',', '260円', 'が', 'プレミアム', 'の', '上乗せ', '分', 'だ', 'が', '、', 'もし', '100万', '馬券', 'でも', '当てよ', 'う', 'もの', 'なら', '更に', '凄まじい', '金額', 'が', 'プラス', 'さ', 'れる', 'こと', 'は', '言うまでもなく', '、', '穴', '党', 'の', '方', 'に', 'は', '従来', 'どおり', '3連単', 'で', '攻める', 'こと', 'を', 'おすすめ', 'し', ...
#
# tag: t4465
# pred_cat: smax
# real_cat: peachy
# words:['※', '追記', 'し', 'まし', 'た', '【', 'Android版', '】', '新しく', 'なっ', 'た', '♪', 'Peachy', 'アプリ', 'の', '使い方', '■■■■■■■■', '3月9日', '(', '金', ')', '更新', '■■■■■■■■', '●', 'お知らせ', '起動', '時', 'に', '新着', '記事', 'を', '自動', '取得', 'する', 'よう', 'に', '変更', 'いたし', 'まし', 'た', '。', '●', '手動', '更新', 'の', '方法', '手動', 'で', '記事', 'を', '更新', 'する', '場合', 'は', '、', '以下', 'の', '手順', 'で', '更新', 'する', 'こと', 'が', 'でき', 'ます', '。', '1', ':', '画面', 'を', 'タッチ', 'し', 'て', '、', '下', 'へ', 'ひっぱっ', 'て', 'ください', '。', '2', ':', 'ひっぱっ', 'た', '後', '、', '手', 'を', '離す', 'と', '、', '取り込み', '中', '画面', 'に', 'なり', 'ます', '。', '3', ':', '取り込み', 'が', '完了', 'する', 'と', '、', '最新記事', 'が', '表示', 'さ', 'れ', 'ます', '。', '■■■■■■■■', '3月5日', '(', '月', ')', '更新', '■■■■■■■■', '●', 'リニューアル', 'し', 'た', 'Peachy', 'Androidアプリ', 'の', '、', '便利', 'な', '機能', 'を', 'ご', '紹介', 'し', 'ます', '！', 'メニュー', 'ボタン', 'が', '増え', 'まし', 'た', '！', '左上', 'の', 'ボタン', 'を', 'タップ', '！', '画面', '左上', 'の', '【', 'メニュー', 'ボタン', '】', 'を', 'タップ', 'する', 'と', '、', 'Peachy', 'の', 'カテゴリー', '一覧', 'へ', '。', '今', '自分', 'が', '一番', '見', 'たい', 'カテゴリ', 'へ', 'すぐ', 'アクセス', 'できる', 'よう', 'に', 'なり', 'まし', 'た', '。', '記事', 'を', 'お気に入り', 'に', '登録', 'でき', 'ます', '！', 'タイトル', 'を', '見', 'て', '「', 'これ', 'は', '後で', 'チェック', 'し', 'たい', '！', '」', 'と', '思っ', 'たら', '★', '型', 'の', 'ボタン', 'を', 'タップ', '！', 'あなた', 'の', '【', 'お気に入り', 'フォルダ', '】', 'に', 'チェック', 'し', 'た', '記事', 'が', '保存', 'さ', 'れ', 'ます', '。', '時間', 'の', 'ある時', 'に', '、', 'まとめ', 'て', '【', 'お気に入り', 'フォルダ', '】', 'から', 'ゆっくり', '読む', 'こと', 'が', 'でき', 'ます', '。', '※', 'お気に入り', 'フォルダ', 'に', '保存', 'できる', '記事', '数', 'に', '制限', 'は', 'ありません', 'が', '、', '元', 'の', '記事', 'が', '削除', 'さ', 'れ', 'た', '、', '期限', 'が', '切れ', 'た', '等', 'の', '理由', 'により', '、', '見れ', 'なく', 'なる', 'こと', 'が', 'あり', 'ます', '。', '記事', 'を', 'シェア', 'しよう', '！', '「', 'この', '記事', 'を', '友達', 'に', 'も', '教え', 'たい', '！', '」', 'と', '思っ', 'たら', '【', 'シェア', '】', 'ボタン', 'を', 'タップ', '！', 'Twitter', '、', 'facebook', '、', 'Email', 'など', 'から', '好き', 'な', 'もの', 'を', '選ん', 'で', '、', '友達', 'に', '伝える', 'こと', 'が', 'でき', 'ます', '。', '※', 'ご', '自身', 'の', '端末', 'に', 'インストール', 'さ', 'れ', 'て', 'い', 'ない', 'アプリ', 'は', '表示', 'さ', 'れ', 'ませ', 'ん', '。', '予め', '御', '了承', 'ください', '。']
#
# tag: t4190
# pred_cat: livedoor-homme
# real_cat: peachy
# words:['ショー', 'も', 'パーク', 'も', '２つ', 'と', 'も', '楽しめる', '贅沢', 'な', '一', '日', 'は', 'いかが', '？\u3000″', 'ゼッド', '＋', 'パーク', '″', 'プラン', 'に', 'ブロガー', 'が', '感動', '\u3000', '2010年', '7月', 'に', '、', '同', '一', '劇場', 'で', 'の', 'ロングラン', '公演', 'として', '日本', '最速', 'で', '100万人', 'の', '来場', 'を', '達成', 'し', 'た', 'シルク・ドゥ・ソレイユ', 'の', '「', 'ZED', '(', 'ゼッド', ')」。', '7月15日', 'から', 'は', '、', 'プラス', '1', ',', '000', '円', 'で', '東京ディズニーランド', 'または', '東京ディズニーシー', 'も', '楽しめる', '、', 'お', '得', 'な', '"', 'ゼッド', '＋', 'パーク', '"', 'プラン', 'が', '発売', 'さ', 'れ', 'て', 'い', 'ます', '。', '\u3000', 'そんな', '中', '、', 'livedoor', 'ブロガー', 'が', '実際', 'に', '"', 'ゼッド', '＋', 'パーク', '"', 'プラン', 'を', '体験', '。', '「', '素晴らしい', 'ショー', 'を', '味わっ', 'た', 'うえ', 'に', '、', 'さらに', '、', 'パーク', 'で', '遊べ', 'て', 'しまう', '、', 'とびきり', '贅沢', 'な', '1日', '」', 'に', '感動', 'する', 'コメント', 'が', '詰まっ', 'た', 'レポート', 'を', '一挙', '公開', 'し', 'ます', '！', '\u3000', 'まずは', '、', '「', 'ゼッド', '」', 'を', '絶賛', 'する', 'ブロガー', 'の', '声', 'から', '。', '「', 'ゼッド', 'の', '為', 'だけ', 'に', 'つくら', 'れ', 'た', '常設', 'シアター', 'ホール', 'で', '、', '設備', 'や', '機材', 'どれ', 'を', 'とっても', '想像', 'を', '絶する', 'スケール', '」', '「"', '太陽', 'の', 'サーカス', '"', 'の', '名', 'に', 'ふさわしい', '、', 'ラグジュアリー', 'な', '芸術', '建築', '」', '\u3000', '大きな', 'ガラス', 'が', '印象', '的', 'な', '「', 'シルク・ドゥ・ソレイユ', 'シアター', '東京', '」', 'は', 'スタイリッシュ', 'で', '都会', '的', 'な', '印象', '。', '舞浜', 'という', 'アクセス', 'し', 'やすい', '立地', 'に', '加え', '、', '「', 'イクスピアリ', '」', 'が', '駅', 'から', 'すぐ', 'の', 'ところ', 'に', 'ある', 'ため', '、', '早め', 'に', '舞浜', 'に', '来', 'て', 'お茶', 'や', 'ランチ', 'を', '満喫', 'する', 'こと', 'も', 'でき', 'ます', 'ね', '。', '劇場', 'の', '中', 'に', '入る', 'と', '、', 'ロビー', 'に', 'は', 'ガラス張り', 'の', '壁', 'と', '高い', '天井', 'で', '外観', 'より', '広い', '印象', 'を', '受け', 'ます', '。', 'ロビー', 'で', 'は', '観劇', 'し', 'ながら', '楽しめる', '食べ物', 'や', '飲み物', '、', 'パンフレット', 'や', 'マグカップ', '、', 'そのほか', 'ピエロ', 'の', '鼻', 'など', '不思議', 'な', 'グッズ', 'など', 'を', '販売', 'し', 'て', 'いる', '売店', 'が', 'あり', '、', '買い物', 'も', '楽しむ', 'こと', 'が', 'でき', 'ます', '。', '「', '半円', '形', 'の', 'ステージ', 'を', '席', 'が', 'ぐるり', 'と', '扇形', 'に', '囲む', '感じ', 'で', '、', 'ステージ', 'サイド', 'の', '席', 'は', 'その', '名', 'の', '通り', 'ステージ', '横', 'です', 'ごく', '近い', '」', '「', '貸出', 'ブランケット', 'が', 'ある', 'こと', 'など', '、', '心から', '楽しん', 'で', 'もらう', '為', 'の', 'スタッフ', 'の', '心配り', 'を', '感じ', 'まし', 'た', '」', 'いよいよ', '観客席', 'に', '足', 'を', '踏み入れる', 'と', '、', 'そこ', 'は', '幻想', '的', 'な', '空間', '。', '2000', 'を', '超える', '観客席', 'や', '圧倒的', 'な', '舞台', 'など', '施設', '自体', 'の', 'クオリティ', 'の', '高さ', 'に', '感動', 'の', '声', 'も', '。', '「', '生', 'バンド', 'による', '演奏', '、', '世界', '24', 'ヶ国', 'から', '集まっ', 'た', '類', 'い', '稀', 'な', '身体能力', 'を', '持っ', 'た', 'アーティスト', '達', '、', 'タロット', 'と', 'ルネッサンス', '期', '芸術', 'の', 'イメージ', 'を', '織り込ん', 'だ', '舞台', 'が', '目', 'の', '前', 'に', '迫っ', 'て', 'くる', '興奮', '。', '幕', 'が', '開い', 'た', '瞬間', 'の', '鳥肌', '」', '\u3000', 'いざ', '、', '開演', '。', '目', 'の', '前', 'で', 'ショー', 'を', '鑑賞', 'し', 'た', 'ブロガー', 'は', '、', '世界', 'レベル', 'の', '技', 'の', '数々', 'と', '、', '舞台', '衣装', 'や', '美術', 'に', '感動', '！', '\u3000', '「', '特撮', 'が', 'すごい', 'とか', '、', 'CG', 'が', 'すごい', 'とか', '、', 'ストーリー', 'の', '伏線', 'が', '云々', 'とか', 'そういう', '次元', 'の', '話', 'で', 'は', 'なく', '、', 'そこ', 'に', 'ある', '人間', 'の', 'エネルギー', 'が', '、', '技', 'が', '、', '肉体', 'が', 'ただただ', '、', '素晴らしい', '」', '「', 'フィナーレ', 'で', 'の', 'なんだか', '突然', '溢れ', 'て', 'き', 'た', '涙。', '確実', 'に', '異世界', '旅行', 'が', 'でき', 'ます', '」', '「"', '果てしなく', '、', '美しく', '。', '紛れ', 'も', 'なく', '、', '神業', '。', '"', 'という', 'パンフレット', 'の', '言葉', 'が', 'ピッタリ', 'でし', 'た', '」', '\u3000', '人間', 'が', '持っ', 'て', 'いる', '力', 'の', '素晴らし', 'さ', '"', 'について', '特筆', 'し', 'て', 'いる', 'ブロガー', 'が', '多数', '。', 'ブロガー', 'の', '皆さん', 'も', '大', '満足', 'の', '様子', 'です', '。', '\u3000', 'そして', '、', '感動', 'の', 'ショー', 'の', '後', 'は', '、', 'お', '楽しみ', 'の', 'パーク', 'へ', '移動', '。', '東京ディズニーランド', 'で', '、', '期間限定', '上映', '中', 'の', '「', 'キャプテンEO', '」', 'を', '楽しん', 'だ', '方', 'や', '、', '東京ディズニーシー', 'で', '夏', '限定', 'の', 'ダンス', 'ショー', '「', 'ボンファイアーダンス', '」', 'を', '楽しん', 'だ', '方', 'など', '、', '過ごし', '方', 'は', 'それぞれ', 'です', 'が', '、', '共通', 'し', 'て', 'いる',  ...
#
# tag: t2651
# pred_cat: livedoor-homme
# real_cat: topic-news
# words:['元', 'オウム', '幹部', '信者', 'しか', '知り', 'え', 'ない', '、', '平田', '容疑者', 'の', '“', '逃亡', '生活', 'の', '謎', '”', 'や', '“', '素顔', '”', '13日', 'に', '放送', 'さ', 'れ', 'た', 'ニッポン放送', 'の', '朝', 'の', '情報', 'ワイド番組', '「', '垣花正', '\u3000', 'あなた', 'と', 'ハッピー', '!」(', '月', '〜', '金', '8時', '〜', '11時', '30分', ')', 'で', '、', '元日', 'に', '逮捕', 'さ', 'れ', 'た', 'オウム真理教', '元幹部', '・', '平田信', '容疑者', 'の', 'かつて', 'の', '教団', '内', 'の', '“', '上司', '”', 'で', 'あっ', 'た', '野田成人', '(', 'の', 'だ', '・', 'なる', 'ひと', ')', '氏', 'が', '出演', 'し', 'た', '。', '番組', 'コメンテーター', 'で', 'ジャーナリスト', 'の', '山路徹', 'から', 'の', '質問', 'に', '答える', '形', 'で', '、', '野田氏', 'は', '、', '平田', '容疑者', 'の', '17年間', 'にわたる', '逃亡', '生活', 'の', '謎', 'や', 'その', '素顔', 'など', '、', '元幹部', '信者', 'だけ', 'しか', '知り', 'え', 'ない', '内容', 'の', '多く', 'の', '“', '真実', '”', 'を', '語っ', 'た', '。', '野田成人', '氏', 'は', '、', '元', 'オウム真理教', '幹部', '信者', 'で', 'アーレフ', '元代表', '。', '1995年', 'の', '地下鉄サリン事件', '前', 'に', 'は', '正悟', '師', 'という', '幹部', 'で', '、', '『', '車両', '省', '大臣', '』', 'と', 'なっ', 'て', 'い', 'た', '。', '今年', '元日', 'に', '出頭', 'し', 'て', '逮捕', 'さ', 'れ', 'た', '平田信', '容疑者', 'は', '『', '車両', '省', '』', 'メンバー', 'で', 'あり', '、', '野田氏', 'は', '平田', '容疑者', 'の', '上司', 'だっ', 'た', '。', '現在', '、', '野田氏', 'は', '宗教', '活動', 'を', '止め', '、', 'ホームレス', 'の', '支援', '活動', 'など', 'を', '行っ', 'て', 'いる', '。', '1995年', '、', '全て', 'の', 'マスコミ', 'の', '中', 'で', 'ただ', '一人', '、', '上九一色村', 'の', 'オウム', 'の', 'サティアン', '内', 'で', 'の', '取材', 'を', '許さ', 'れ', 'た', '山路徹', 'の', '質問', 'に', '電話', 'で', '答え', 'た', '。', '平田', '容疑者', '逮捕', 'の', '一報', 'を', '聞い', 'て', '？', '「', 'まだ', '生き', 'て', 'い', 'た', 'の', 'か', 'という', '驚き', 'が', '強かっ', 'た', '。', '手配', 'さ', 'れ', 'て', '仕事', 'が', 'できる', '訳', 'で', 'も', 'ない', 'ので', '死ん', 'で', 'しまっ', 'た', 'と', '考える', 'の', 'が', '普通', 'だ', 'と', '思う', '」', '目黒', '公証人役場', '事務', '長', '拉致監禁', '致死', '事件', 'について', '犯意', 'を', '否定', 'する', '供述', 'を', 'し', 'て', 'いる', 'が', '？', '「', '平田', '容疑者', 'は', '犯罪', 'の', '中心', '的', 'な', '役割', 'を', '任さ', 'れる', 'よう', 'な', '人物', 'で', 'なかっ', 'た', 'こと', 'は', '事実', '。', '計画', 'の', '全容', 'を', '知ら', 'なかっ', 'た', 'として', 'も', 'おかしく', 'ない', '。', '犯罪行為', 'に', '関わる', '中', 'で', '脇役', 'だっ', 'た', '事', 'は', '間違い', 'ない', '」', '平田', '容疑者', 'は', '元々', 'どんな', '人物', 'か', '？', '「', '人', 'あたり', 'は', 'ソフト', 'で', '、', '教団', '内', 'で', 'は', '一', '歩', '引い', 'た', 'よう', 'な', '立場', 'だっ', 'た', '」', '逮捕', '後', '、', '信仰心', 'は', 'もう', '無い', 'と', '言っ', 'て', 'いる', 'が', '本心', 'だ', 'と', '思う', 'か', '？', '「', '滝本太郎', '弁護士', 'が', '接見', 'し', 'た', '時', 'に', '平田', '容疑者', 'が', 'そう', '言っ', 'て', 'いる', 'なら', '信頼', 'できる', 'と', '思う', '。', '平田', '容疑者', 'の', '性格', 'から', '、', '松本智津夫', '死刑囚', 'の', '死刑執行', '延期', 'の', 'ため', 'に', '涙', 'を', '流し', 'て', '演技', 'し', '偽っ', 'て', 'いる', 'と', 'は', '思わ', 'ない', 'ので', '脱会', 'は', '事実', 'だろ', 'う', '」', '95年', 'の', '強制捜査', 'の', '直前', 'に', '教団', 'から', 'の', '逃走', 'の', '指示', 'は', 'どう', 'だっ', 'た', 'か', '？', '「', '私', '（', '野田', '）', 'は', '村井秀夫', 'から', '逃げろ', 'と', '言わ', 'れ', 'た', '。', '平田', '容疑者', 'は', '当時', 'の', '上司', 'だっ', 'た', '新実智光', 'から', '言わ', 'れ', 'た', 'と', '思う', '。', '」', '斎藤明美', '容疑者', 'が', '逮捕', '時', 'に', '800万円', 'を', '所持', 'し', 'て', 'い', 'た', 'と', 'いう', 'が', '、', '逃走', '資金', 'について', 'は', 'どう', '思う', '？', '「', '私', 'も', '村井', 'から', '資金', 'を', '貰っ', 'た', '。', '平田', '容疑者', 'と', '斎藤', '容疑者', 'も', '貰っ', 'た', 'と', '思う', '。', '教団', 'に', 'は', '強制捜査', '直前', 'に', 'は', '10億円', '近い', '資金', 'が', 'あっ', 'た', 'と', '思う', '」', '國松孝次', '警察庁長官狙撃事件', 'に', '平田', '容疑者', 'は', '関与', 'し', 'て', 'いる', 'か', '？', '「', '早川紀代秀', '死刑囚', 'の', '供述', 'で', 'は', '平田', '容疑者', 'の', '関与', 'は', '無く', '、', '隠す', '理由', 'も', 'ない', 'ので', '関与', 'は', 'し', 'て', 'い', 'ない', 'と', '思う', '」', '逃亡', '生活', '中', '、', '斎藤明美', '容疑者', 'ひとり', 'で', '匿え', 'る', 'もの', 'か', '？', '協力', '者', 'が', 'い', 'た', 'の', 'で', 'は', '？', '「', '斎藤', '容疑者', 'ひとり', 'が', '働い', 'て', 'つましく', '生活', 'すれ', 'ば', '十分', 'やっ', 'て', 'いけ', 'た', 'の', 'で', 'は', 'ない', 'か', '。', '穿', 'り', '返し', 'て', 'も', '何', 'か', '出', 'て', 'くる', 'と', 'は', '思え', 'ない', '」', '野田', 'さん', 'は', '松本智津夫', '死刑囚', 'の', '死刑執行', 'について', 'どう', '思う', '？', '「', '早く', '死刑', ' ...
#
# tag: t3266
# pred_cat: kaden-channel
# real_cat: topic-news
# words:['サムスン', 'の', 'アンドロイド', '搭載', 'カメラ', 'が', '韓国', 'で', '話題', 'に', '韓国', 'の', 'IT', '専門', 'ニュースサイト', '「', 'ブロター・ネット', '」', 'は', '、', '29日', '、', 'サムスン', 'が', '公開', 'し', 'た', 'アンドロイド', '搭載', 'の', 'デジタルカメラ', '「', 'ギャラクシー', '・', 'カメラ', '」', 'の', 'レビュー', 'を', '掲載', 'し', 'て', 'いる', '。', 'アンドロイド', '4', '.', '1', '・', 'ジェリービーンズ', 'が', '搭載', 'さ', 'れ', 'て', 'いる', 'この', '商品', 'について', '、', '記事', 'で', 'は', '「', 'ギャラクシー', '・', 'カメラ', 'が', 'カメラ', 'な', 'の', 'か', 'スマホ', 'な', 'の', 'か', '曖昧', '」', 'と', '説明', 'し', 'て', 'いる', '。', '同', '製品', 'は', 'アンドロイド', 'OS', 'が', '入っ', 'て', 'いる', '以上', '、', '既存', 'の', 'ギャラクシー', '・', 'スマートフォン', 'と', '似', 'て', 'いる', '。', 'アプリ', 'の', 'ダウンロード', '、', '音楽', '鑑賞', '、', 'インターネット', 'も', 'もちろん', '可能', 'だ', '。', '興味深い', 'の', 'は', 'Wi-Fi', 'だけ', 'で', 'は', 'なく', '、', '3G', '、', '4', 'G', '回線', 'も', '使用', 'できる', 'ため', '、', '通信事業', '社', 'を通して', '購入', 'し', 'なけれ', 'ば', 'なら', 'ない', '一方', '、', '電話', '機能', 'は', 'ない', '。', '記事', 'で', 'は', '同', '製品', 'を', '「', '共有', '機能', 'に', '焦点', 'が', '当て', 'られ', 'た', '製品', '」', 'と', '結論', '付け', 'た', '。', '記事', 'コメント欄', 'に', 'は', '「', 'カメラ', '持ち歩く', 'ため', 'に', '毎月', '一定', 'の', '額', 'を', '支払え', 'と', 'いう', 'こと', 'だろ', 'う', '」', '「', '携帯', 'に', 'デジカメ', 'の', '望遠レンズ', 'を', 'つける', 'と', 'それ', 'で', '電話', 'しない', 'だろ', 'う', '。', 'カメラ', 'は', 'カメラ', 'で', '特', '化', 'し', 'て', '電話', 'は', '電話', '」', '「', '写真', 'を', '取っ', 'た', '瞬間', 'に', '送ら', 'なけれ', 'ば', 'なら', 'ない', '職業', 'の', '人', 'は', '少ない', 'と', '思う', '。', '産業スパイ', '用', 'か', '、', 'それとも', '記者', 'や', 'パパラッチ', '用', 'か', '」', '「', 'アンドロイド', 'は', 'もともと', '洗濯機', '、', '冷蔵庫', '、', 'テレビ', 'など', 'に', 'も', '使える', 'よう', 'に', '設計', 'さ', 'れ', 'て', 'いる', '」', 'など', '、', 'ユーザー', 'から', '様々', 'な', '反響', 'が', '寄せ', 'られ', 'て', 'いる', '。']
#
# tag: t4108
# pred_cat: dokujo-tsushin
# real_cat: peachy
# words:['きつい', 'ダイエット', 'は', 'もう', 'しない', '！', '食欲', 'の', '秋', 'で', 'も', '目', '指せる', '理想', 'の', 'ボディ', '食欲', 'の', '秋', 'は', 'ダイエット', 'の', '大敵', 'と', 'いう', 'が', '、', 'これ', 'は', 'どうやら', '万国', '共通', '。', 'ダイエット', '先進国', 'アメリカ', 'の', '著名', 'な', '栄養士', '兼', 'トレーナー', 'で', 'ある', 'マーク', '・', 'マクドナルド', '氏', 'は', '「', '秋', 'は', '肌の露出', 'が', '減っ', 'て', '油断', 'し', 'て', 'しまう', 'し', '、', '美味しい', 'もの', 'が', '多い', 'ので', '危険', '」', 'と', '月刊誌', '「', 'SELF', 'Magazin', '」', 'で', 'コメント', 'を', '残し', 'て', 'い', 'た', '。', 'さらに', '同氏', 'は', '「', '食事', 'は', '少量', 'ずつ', '回数', 'を', '分けて', '食べる', '」', '「', '炭水化物', 'を', '先', 'に', '食べ', 'ない', '」', '「', 'エクササイズ', 'を', 'サボら', 'ない', '」', 'という', '三', 'ヵ条', 'を', '掲げ', 'て', '、', '秋', '太り', 'に', '警鐘', 'を', '鳴らし', 'て', 'いる', '。', 'つまり', 'は', '栄養', 'バランス', 'の', '良い', '食事', 'と', '適度', 'な', '運動', 'を', 'すれ', 'ば', '痩せる', '・', '・', '・', 'と', '。', 'もちろん', '、', 'そんな', 'こと', 'は', '百', 'も', '承知', 'だ', '。', '最近', 'で', 'は', '日本', 'で', 'も', '「', '美女', 'ガーブーム', '」', 'で', '女子', 'の', '間', 'で', 'ジョギング', 'が', '流行っ', 'たり', '、', '某社', 'の', '社員食堂', 'の', 'メニュー', 'が', '書籍', '化', 'さ', 'れ', 'て', 'ベストセラー', 'と', 'なっ', 'たり', 'し', 'て', 'いる', '。', 'だが', '、', '仕事', 'を', '持っ', 'て', 'いる', '女子', 'や', '忙しい', '主婦', 'の', '方', 'にとって', 'は', '、', '毎日', 'きちんと', '食事', 'を', '制限', 'し', 'たり', '、', '運動', 'を', '続ける', 'の', 'は', 'なかなか', '難しい', 'もの', '。', '逃げ口上', 'で', 'は', 'ない', 'が', '、', '無理', 'な', 'ダイエット', 'を', 'し', 'て', 'しまう', 'と', '、', '継続', 'でき', 'ず', 'に', 'リバウンド', 'し', 'て', 'しまう', '可能性', 'も', '低く', 'は', 'ない', '。', 'ちなみに', 'COBS', 'オンライン', 'の', '調査', 'で', 'も', '女子', 'ダイエッター', 'の', '何', 'と', '82%', 'が', 'ダイエット', 'に', '失敗', 'を', 'し', 'た', '経験', 'が', 'ある', 'という', 'こと', '。', '中でも', 'フルーツ', '系', '単品', 'ダイエット', 'や', '絶食', '・', '断食', 'など', 'の', 'ダイエット', 'に', 'は', '挫折', '者', 'が', '多く', '、', '鬼門', '状態', '。', 'もちろん', '、', '急激', 'な', '運動', 'だって', 'ケガ', 'や', '、', '熱中症', 'など', 'の', '原因', 'と', 'なっ', 'て', 'しまう', 'ので', 'かなり', 'の', '注意', 'が', '必要', 'だ', '。', 'そんな', '中', '、', 'あくまでも', '自然', 'で', '健康', '的', 'な', 'ダイエット', 'を', '目指す', 'OL', 'や', '主婦', 'の', '方々', 'の', '間', 'で', 'ひそか', 'な', 'ブーム', 'と', 'なり', 'つつ', 'ある', 'の', 'が', 'プーアール', '茶', 'を', '飲む', '、', 'プーアール', '茶', 'ダイエット', '。', '「', 'なぜ', 'プーアール', '茶', '?」', 'と', '思う', '方', 'も', 'いる', 'かも', '知れ', 'ない', 'が', '、', 'そもそも', 'プーアール', '茶', 'と', 'は', '中国茶', 'の', '中', 'の', '緑茶', 'を', '黒', '麹菌', 'で', '発酵', 'さ', 'せ', 'た', 'もの', 'で', '、', '血行', 'や', 'お', '通じ', 'を', '良く', 'し', 'たり', '、', 'さらに', 'は', '脂肪', '分解', '作用', 'が', 'ある', 'と', 'さ', 'れ', 'て', 'いる', '。', 'ただ', '、', 'その', '効果', 'は', '品質', 'に', '比例', 'する', 'よう', 'で', '、', '高級', 'プーアール', '茶', 'は', 'なんと', '20', 'グラム', 'で', '5', ',', '000', '円', '以上', 'の', '値', 'が', 'つく', 'こと', 'も', 'ある', 'と', 'か', '。', 'しかし', '、', '最近', 'で', 'は', 'ティーライフ', 'が', '出し', 'て', 'いる', 'ダイエットプーアール', '茶', 'は', 'ママ', 'さん', 'タレント', 'を', '中心', 'に', 'ブログ', 'でも', '取り上げ', 'られ', 'て', '、', '愛飲', '者', 'が', '122', '万', '人', 'に', 'も', '達する', 'ほど', 'の', '人気ぶり', '。', '身体', '的', 'な', '負担', 'も', '面倒臭', 'さ', 'も', '無い', 'し', '、', '何より', 'お', '財布', 'に', '負担', 'を', 'かける', 'こと', 'なく', '、', '手軽', 'に', '健康', '的', 'な', 'ダイエット', 'を', '継続', 'できる', 'と', '評判', 'だ', '。', 'そして', '気', 'に', 'なる', 'お', '味', 'の', '方', 'だ', 'が', '、', 'プーアール', '茶', 'は', '健康', '的', 'な', 'イメージ', 'が', 'ある', '一方', 'で', '飲み', 'にくい', 'という', 'イメージ', 'も', 'ある', '。', 'しかし', 'そこ', 'は', '中国', '雲南省', 'の', '手', '摘み', '100%', 'の', '茶', '葉', 'を', '使用', 'し', '、', '蒸気', '殺菌', 'によって', 'さらに', '飲み', 'やすく', 'し', 'て', 'おり', '、', 'ダイエット食品', 'に', 'も', '関わら', 'ず', '美味しく', '続け', 'られる', 'という', 'こと', 'だ', '。', '現在', 'で', 'あれ', 'ば', 'お', '試し', 'で', '10日間', 'の', 'お', '試し', 'パック', 'を', '980円', 'で', '提供', 'し', 'て', 'いる', '上', 'に', '、', '30日間', '返品', '・', '返金保証', 'も', 'し', 'て', 'いる', 'の', 'だ', 'から', '、', 'メーカー', 'は', 'かなり', 'の', '自信', 'を', '持っ', 'て', 'いる', 'の', 'で', 'は', 'ない', 'だろ', 'う', 'か', '。', 'こうした', 'ダイエット', 'アイテム', '見', 'て', 'みる', 'と', '、', 'やはり', '成功', 'の', '秘訣', 'は', '無理', 'を', 'し', 'ない', 'こと', 'に', '思え', 'て', 'くる', '。', '今年', 'の', '秋', 'は', '、', '激しい', '運動', 'や', '厳しい', '食事制限', 'など',  ...
#
# tag: t3924
# pred_cat: dokujo-tsushin
# real_cat: peachy
# words:['女性', 'を', '潤す', '新た', 'な', '注目', 'ワード', 'は', '“', 'アミノ酸', '”', '\u3000', '8月', 'も', '残す', 'ところ', '10日', '余り', '。', '秋', 'の', 'はじまり', 'と共に', '気', 'に', 'なっ', 'て', 'くる', 'の', 'が', 'お', '肌', 'の', '乾燥', 'ケア', 'だ', '。', '潤い', 'と', 'ハリ', 'の', 'ある', '肌', 'の', '為', 'に', 'ヒアルロン酸', 'と', 'コラーゲン', 'に', '着目', 'し', 'た', '「', 'ベキュア', 'スキンパーフェクトスフィア', '」', 'シリーズ', 'に', '、', '「', 'アミノ酸', '」', 'に', '着目', 'し', 'た', 'ニュー', 'アイテム', 'が', '登場', 'し', 'た', '。', '\u3000', '皮膚', '成分', 'の', 'ほとんど', 'は', 'アミノ酸', 'によって', '占め', 'られ', 'て', 'おり', '、', '素肌', 'は', '良質', 'な', 'アミノ酸', 'を', '常に', '求め', 'て', 'いる', '。', '今回', '新', 'シリーズ', 'は', '、', 'アルギニン', '、', '保', '湿', '作用', 'の', 'ある', 'グルタミン酸', '、', '角質', 'を', '形成', 'する', 'セリン', '、', 'ハリ', '感', 'を', 'サポート', 'する', 'プロリン', 'を', 'カプセル', 'に', '内包', 'し', '、', '肌', 'に', '速攻', 'アプローチ', '。', '\u3000', '特に', '、', 'ベキュア', '初', 'と', 'なる', 'バーム', 'タイプ', 'の', 'メイク', '落とし', 'は', '、', '毛穴', 'の', '奥', 'の', '汚れ', 'まで', 'すっきり', '落とし', 'つつ', '、', 'マッサージ', 'も', 'できる', 'という', '1', '品', '2', '役', 'の', '楽ちん', 'コスメ', '。', 'マッサージ', 'だけ', 'だ', 'と', '続ける', 'の', 'は', '難しい', 'が', '、', '毎日', '行う', 'クレンジング', 'と共に', '肌', 'に', '溜まっ', 'た', '汚れ', 'の', '排出', 'を', '促し', '、', 'すっきり', 'と', 'し', 'た', '輪郭', 'と', 'ワントーン', '明るい', '肌', 'を', '手', 'に', '入れる', 'こと', 'が', 'できる', '。', '\u3000', 'また', '、', '十分', 'な', '睡眠時間', 'が', 'とれ', 'ず', '、', '肌', '本来', 'の', '再生', '能力', 'が', '不足', 'し', 'て', 'いる', '現代', '女性', 'の', '為', 'に', '睡眠', '中', 'の', '肌', '潤い', '生理', 'に', '注目', 'し', 'た', 'ナイト', 'クリーム', 'も', '登場', '。', '眠っ', 'て', 'いる', '間', 'に', '潤い', 'と', 'ハリ', '感', 'を', '与え', '、', '朝', '目覚め', 'た', '時', 'に', 'は', '艶', 'めく', '素肌', 'が', '手', 'に', '入る', '。', '\u3000', '今年', 'の', '秋', 'の', '乾燥', 'ケア', 'に', 'は', 'アミノ酸', '。', '忙しい', '日々', 'で', '失い', 'がち', 'な', '潤い', 'を', '、', '手軽', 'に', '補充', 'し', '、', '艶', '肌', 'を', '手', 'に', '入れよ', 'う', '。', 'アミノアクトクレンジングバーム', '、', 'アミノアクトクレンジングフォーム', '、', 'アミノエフェクティブスリープ', 'は', '8月20日', 'より', '販売開始', '。', '・', 'ベキュア', 'オンラインショップ']
#
# tag: t3212
# pred_cat: sports-watch
# real_cat: topic-news
# words:['勝利', '後', '、', '相手', '選手', 'を', '慰める', 'なでしこジャパン', '・', '宮間あや', 'に', '米国', 'ユーザー', 'から', '称賛', '相次ぐ', '米国', '「', 'NBCニュース', '」', 'の', 'マルチメディア', '担当', 'ナタリア・ジメニーズ', '氏', 'が', '、', '6日', '行わ', 'れ', 'た', 'なでしこジャパン', 'と', 'フランス', 'と', 'の', '準決勝', 'について', '触れ', '、', '米国', 'の', 'ネット掲示板', 'など', 'で', '話題', 'と', 'なっ', 'て', 'いる', '。', 'この', '日', '、', 'なでしこジャパン', 'に', '2', '−', '１', 'で', '敗れ', 'た', 'フランス', 'の', 'カミーユ・アビリー', '選手', 'は', '呆然', 'として', 'グラウンド', 'で', 'へ', 'たり', '込み', '泣い', 'て', 'い', 'た', '。', 'ブログ', 'に', 'は', '、', 'アビリー', '選手', 'を', '宮間あや', '選手', 'が', '慰め', 'て', 'いる', '様子', 'を', '収め', 'た', '写真', 'を', '掲載', 'し', '、', 'さらに', '「', '2人', 'の', '間', 'で', '交わさ', 'れ', 'た', '言葉', 'を', '知る', 'こと', 'は', 'でき', 'ない', 'し', '、', '言語', 'の', '壁', 'も', 'あっ', 'た', 'だろ', 'う', 'が', '、', '彼女ら', 'の', 'ボディ・ランゲージ', 'は', 'ちゃんと', '語っ', 'て', 'いる', '」', '「', 'この', 'オリンピアン', 'たち', 'は', '優れ', 'た', '選手', 'で', 'あり', 'ながら', '、', '本当', 'の', 'スポーツ', '精神', 'を', 'も', '見せ', 'て', 'くれ', 'た', '」', 'と', '綴っ', 'て', 'いる', '。', 'ブログ', 'コメント欄', 'に', 'は', '、', '「', '美しい', '試合', 'だ', '」', '「', 'これ', 'は', '日本の文化', '的', 'な', 'もの', 'で', '勝利', 'を', '相手', 'に', '見せつけ', 'ず', 'に', '、', '心から', 'なだめる', '傾向', 'が', 'ある', 'と', '思う', '」', 'など', '、', '宮間', 'の', '行動', 'を', '称える', '声', 'が', '相次い', 'だ', '。', 'また', '、', '「', '宮間', 'と', 'アビリー', 'は', 'Los Angeles', 'SOL', 'っていう', 'アメリカ', 'の', 'チーム', 'に', '一緒に', '所属', 'し', 'て', 'い', 'た', '。', 'お互い', '知り合い', 'で', '言語', 'の', '壁', 'も', '薄い', 'はず', '」', 'と', '2人', 'の', '関係', 'を', '説明', 'する', 'ユーザー', 'も', '。', 'さらに', '、', '欧州', 'に', '向かう', '航空機', 'で', '、', '男子', 'に', 'は', 'ビジネスクラス', 'の', '席', 'が', '与え', 'られ', 'た', 'の', 'に対し', '、', '女子', 'は', 'エコノミークラス', 'だっ', 'た', 'こと', 'から', '、', '「', '日本', '女子サッカー', 'チーム', 'に', 'は', '以前', 'から', '深い', '印象', 'を', '持っ', 'て', 'いる', '。', '我々', 'が', '求める', 'べき', '五輪', '精神', 'の', '事例', 'だ', 'と', '思う', '。', '後', 'は', '日本', 'IOC', 'が', '彼女ら', 'に', 'ビジネスクラス', 'か', 'ファーストクラス', 'の', '帰国', '便', 'を', '用意', 'する', 'こと', 'ね', '」', 'という', 'コメント', 'も', '寄せ', 'られ', 'て', 'い', 'た', '。']
#
# tag: t3476
# pred_cat: dokujo-tsushin
# real_cat: livedoor-homme
# words:['サラリーマン', '格差社会', 'の', '現実', '、', '借金', 'or', '貯蓄', '1', ',', '000', '万', '円', 'に', '二極化', '6月28日', '、', 'livedoor', 'HOMME', 'にて', '、', 'オトナ', 'の', 'お小遣い', '事情', 'に関する', '緊急', 'アンケート', 'を', '実施', 'し', 'た', '。', '短い', '時間', 'ながら', '累計', '8', ',', '416', '（', '29日', '10時', '30分', '現在', '）', 'も', 'の', '非常', 'に', '多く', 'の', '方々', 'に', 'ご', '協力', 'いただい', 'た', '。', 'この', '場', 'を', 'お', '借り', 'し', 'て', 'お礼', '申し上げ', 'たい', '。', 'さて', '、', 'この', '緊急', 'アンケート', 'で', 'は', '、', '驚く', 'べき', '結果', 'が', '明らか', 'に', 'なっ', 'た', '。', '今回', 'は', 'アンケート', '結果', 'を', 'もと', 'に', '、', '僕ら', '現代', 'サラリーマン', 'の', '貯蓄', '事情', 'に', '迫っ', 'て', 'み', 'たい', 'と', '思う', '。', '貯蓄', '1000万円', '以上', 'が', '約', '2割', '一', '問', '目', 'で', 'は', '、', 'ずばり', 'ストレート', 'に', '「', '現在', 'の', '貯蓄額', 'を', '教え', 'て', 'ください', '？', '」', 'という', '質問', 'を', 'さ', 'せ', 'て', 'いただい', 'た', '。', '有効', '回答', 'は', '3703', '。', '選択肢', 'は', '「', '借金', 'あり', '」', '「', 'ない', '」', '「', '〜', '100万円', '」', '「', '〜', '200万円', '」', '「', '〜', '300万円', '」', '「', '〜', '400万円', '」', '「', '〜', '500万円', '」', '「', '〜', '600万円', '」', '「', '〜', '700万円', '」', '「', '〜', '800万円', '」', '「', '〜', '900万円', '」', '「', '〜', '1', ',', '000', '万', '円', '」', '「', '1', ',', '000', '万', '円', '以上', '」', 'だ', '。', 'あなた', 'は', '、', 'どの', '項目', 'が', '最も', '多く', 'の', 'クリック', 'を', '集め', 'た', 'と', 'お', '考え', 'だろ', 'う', 'か', '？', '答え', 'は', '「', '借金', 'あり', '」', '（', '21', '.', '9', '）', '％', 'で', 'あっ', 'た', '。', '次点', 'は', '「', '1', ',', '000', '万', '円', '以上', '」', '（', '19', '.', '3', '％', '）', 'で', 'あっ', 'た', '。', '借金', 'あり', 'or', '1', ',', '000', '万', '円', '以上', 'に', '二分', 'さ', 'れ', 'て', 'いる', 'この', '世の中', '。', '悲しい', 'か', 'な', '、', '何とも', 'コントラスト', 'が', '効い', 'て', 'いる', 'で', 'は', 'ない', 'か', '。', 'さて', 'さて', '、', '「', '1', ',', '000', '万', '円', '以上', '」', 'の', '貯蓄', 'と', '聞い', 'て', '多い', 'なぁ', '〜', '、', 'と', '心', 'で', 'つぶやい', 'た', '、', 'そこ', 'の', '貴方', '。', '今', 'から', '少し', 'こわい', '話', 'を', 'さ', 'せ', 'て', 'いただき', 'たい', '。', '読ん', 'だ', '後', '、', '違っ', 'た', '意味', 'で', '背筋', 'が', '凍る', 'はず', 'だ', '。', '定年', '後', 'に', '必要', 'な', '貯蓄', '額', '過日', '、', '厚生労働省', 'は', '継続', '雇用', '制度', 'を', '強化', 'し', '65歳', 'まで', 'の', '雇用', 'を', '企業', 'に', '義務付ける', '報告書', 'を', 'まとめ', 'た', '。', '給与', 'を', '貰える', '年齢', 'が', '上がる', 'の', 'は', '望ましい', 'こと', 'な', 'の', 'かも', 'しれ', 'ない', 'が', '、', '実際', 'に', '定年', 'を', '迎え', 'た', 'とき', '、', '僕たち', 'は', 'どの', 'よう', 'に', '暮らし', 'て', 'いけ', 'ば', 'よい', 'の', 'だろ', 'う', 'か', '。', '例えば', '、', '夫婦', 'が', '定年', '後', 'に', '必要', 'と', 'する', '生活費', 'は', '最低', 'で', 'も', '月', '平均', 'で', '23', '.', '2万円', '、', 'ゆとり', 'ある', '生活', 'を', '送り', 'たい', '場合', 'は', '38', '.', '3万円', 'と', '試算', 'さ', 'れ', 'て', 'いる', '(', '平成19年度', '\u3000', '生活保障', 'に関する', '調査', 'より', ')。', '今後', '、', '定年', 'が', '65歳', 'まで', '引き上げ', 'られ', 'た', 'として', '、', '夫婦', 'の', '平均寿命', 'を', '夫', '82歳', '、', '妻', '87歳', 'と', '設定', 'し', '、', '定年', '後', 'に', '必要', 'な', '貯蓄', '額', 'を', '計算', 'し', 'て', 'みる', 'と', '、', '最低', 'で', 'も', '約', '5', ',', '700万円', '、', 'ゆとり', 'の', 'ある', '生活', 'を', '営み', 'たい', 'の', 'で', 'あれ', 'ば', 'およそ', '9', ',', '400万円', 'の', '貯蓄', 'が', '必要', 'と', 'いわ', 'れ', 'て', 'いる', '。', '(', '日本FP協会', 'の', '試算', 'より', ')', '最低', 'で', 'も', '5', ',', '700万円', '…', '…。', '最低', 'で', 'も', '5', ',', '700万円', '…', '…。', '最低', 'で', 'も', '5', ',', '700万円', '…', '…。', '三度', 'も', '復唱', 'すれ', 'ば', '、', '脳', 'に', '刻み込ま', 'れ', '、', '必ずや', 'この', 'ネタ', 'を', '同僚', '・', '家族', 'に', '話し', 'たく', 'なる', 'だろ', 'う', '。', 'それだけ', '衝撃', '的', 'な', '金額', 'だ', '。', 'では', '、', '僕たち', 'は', '毎月', 'どれ', 'くらい', '貯蓄', 'を', 'すれ', 'ば', '良い', 'の', 'か', '。', '若干', 'キレ', '気味', 'に', '計算', 'し', 'た', 'ところ', '、', '定年', '後', 'の', '貯蓄額', '5', ',', '700万円', 'を', '目指し', 'た', '場合', '、', '30歳', 'から', 'だ', 'と', '毎月', 'およそ', '13万円', '、', '40歳', 'から', 'だ', 'と', 'およそ', '19万円', 'も', '貯蓄', 'に', 'まわさ', 'ね', 'ば', 'なら', 'ない', 'こと', 'が', 'わかっ', 'た', '。', '今', 'すぐ', '節約', 'でき', 'そう', 'な', '金額', 'は', 'いくら', '？', 'はたして', '毎月', '13万円', 'も', '貯蓄', 'に', 'まわし', 'て', 'いる', '人', 'が', 'いる', 'の', 'だろ', 'う', 'か',  ...
#
# tag: t5600
# pred_cat: movie-enter
# real_cat: dokujo-tsushin
# words:['独女', '的', '映画', 'レビュー', 'vol.8', '\u3000', '『', 'ブラック・スワン', '』', '「', '自分', 'を', '解き放て', '！', '」', '「', '感じろ', '！', '」', '「', '誘惑', 'しろ', '！', '」', '“', '完璧', '”', 'を', '目指す', 'が', '故に', '、', '心', 'も', '体', 'も', 'コントロール', 'し', 'て', 'き', 'た', '優等生', 'の', 'バレリーナ', '、', 'ニナ', '（', 'ナタリー・ポートマン', '）', '。', 'そんな', '彼女', 'に', '“', '足り', 'ない', 'もの', '”', 'は', '、', '“', 'パッション', '（', '情熱', '）', '”', '。', '「', '不感症', 'の', '踊り', 'だ', '！', '」', 'と', '罵ら', 'れ', '、', '「', '家', 'に', '帰っ', 'て', '自分', 'で', '自分', 'を', '触っ', 'て', 'こい', '！', '」', 'と', '課題', 'を', '出さ', 'れ', '、', '“', '技術', '”', 'は', '完璧', 'な', 'のに', '、', '“', '女', '”', 'として', 'の', '魅力', '（', '色気', '）', 'が', 'ない', 'ため', 'に', '、', 'せっかく', '選ば', 'れ', 'た', 'プリマ', 'の', '役', 'を', '降ろさ', 'れ', 'そう', 'に', 'なる', '屈辱', '。', '技術', 'は', '自分', 'の', '方', 'が', '上', 'な', 'のに', '、', 'セクシー', 'で', '開放', '的', 'な', 'バレリーナ', '、', 'リリー', '（', 'ミラ・クニス', '）', 'が', 'コーチ', 'に', '気に入ら', 'れる', '様子', 'を', '見', 'て', '、', 'ニナ', 'の', 'パラノイド', 'は', '加速', 'する', '。', '『', 'このまま', 'だ', 'と', 'リリー', 'に', '座', 'を', '奪わ', 'れる', '。', '何とか', '自分', 'を', '“', '解放', '”', 'し', 'なけれ', 'ば', '』', 'ただ', 'その', '一心', 'で', '、', '家', 'に', '帰っ', 'て', 'は', '自慰', '行為', 'に', '耽り', '、', '異常', 'な', 'まで', 'に', 'リリー', 'に', '執着', 'し', 'て', 'いく', 'ニナ', '。', '次第に', '自分', 'の', 'ダークサイド', 'の', '分身', 'が', 'リリー', 'と', '重なり', '、', '天使', 'が', '悪魔', 'へ', 'と', '変わっ', 'て', 'いく', '…', '…。', 'もしか', 'する', 'と', '、', 'リリー', 'など', '存在', 'し', 'なかっ', 'た', 'の', 'かも', 'しれ', 'ない', '。', '“', '女', '”', 'として', 'の', '開花', 'に', '苦しむ', 'ニナ', 'の', '葛藤', 'が', '、', '自分', 'に', '“', '足り', 'ない', '”', 'もの', 'を', '全て', '持っ', 'て', 'いる', '、', 'リリー', 'という', '妄想', '上', 'の', '“', '分身', '”', 'を', '生み出し', '、', '目', 'の', '前', 'に', 'ある', '自分', 'の', '“', '壁', '”', 'と', '、', '闘っ', 'て', 'い', 'た', 'の', 'かも', 'しれ', 'ませ', 'ん', '。', '完全', 'に', 'ダークサイド', 'に', '陥り', '、', '舞台', 'を', '終え', 'た', 'ニナ', 'が', '最後', 'に', '言う', '、', '「', 'I', 'felt', 'it', '（', '感じ', 'た', 'わ', '）', '」', 'この', '台詞', 'を', '聞い', 'て', '、', '涙', 'が', '溢れ', 'まし', 'た', '。', '精神', 'を', '病み', '、', '命', 'を', 'かけて', '手', 'に', '入れ', 'た', '“', '達成感', '”', '。', 'たった', 'この', '一瞬', 'だけ', 'でも', '、', '彼女', 'が', '幸せ', 'だっ', 'た', 'と', '思い', 'たい', '。', '“', '頂点', 'を', '目指す', '者', '”', 'の', '尋常', 'で', 'ない', 'プレッシャー', 'と', '、', '女', '”', 'なら', 'では', 'の', 'デリケート', 'な', '苦悩', 'が', '生み出し', 'た', '“', '悪夢', '”', '。', '頂点', 'を', '目指す', '様', 'な', '極限', '状態', 'に', '陥っ', 'た', 'こと', 'の', 'ない', '女性', 'で', 'も', '、', '自分', 'に', '“', '足り', 'ない', 'もの', '”', 'に対する', 'トラウマ', 'や', '、', '異常', 'な', 'まで', 'の', '執着', 'という', '“', '女', '”', 'として', 'の', '苦悩', '部分', 'に', 'は', '、', '誰', 'も', 'が', '感情', '移入', 'し', 'て', 'しまう', 'はず', 'です', '！', '！', '自慰', '行為', 'や', '女同士', 'の', 'セックス', 'シーン', '、', '役', '（', 'ブラック・スワン', '）', 'が', '完全', 'に', '乗り移っ', 'た', '渾身', 'の', 'ダンス', 'シーン', 'など', '、', '2011年度', 'の', '“', 'ゴールデン・グローブ賞', '”', '、', '“', 'アカデミー賞', '”', 'で', '最優秀主演女優賞', 'を', '獲得', 'し', 'た', 'ナタリー・ポートマン', 'の', '入魂', 'の', '演技', 'と', '美し', 'さ', 'を', '見る', 'だけ', 'でも', '“', '女子', '度', '”', 'が', '上がる', '！', '一人', 'で', 'も', '多く', 'の', '女性', 'に', '観', 'て', '欲しい', '、', 'オススメ', 'の', '一本', 'です', '！', '！', '（', '安部沙織', '）', '(', 'C', ')', '2010', 'Twentieth', 'Century', 'Fox', '.']
